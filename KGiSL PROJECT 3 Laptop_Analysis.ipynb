# %% [markdown]
# # PROJECT INTRODUCTION: LAPTOP DATA ANALYSIS

# %% [markdown]
# # Four Major Parts:

# %% [markdown]
# #### * This project focuses on performing an in-depth analysis of a dataset containing specifications and pricing information for a wide range of laptops. The dataset includes key attributes such as brand, screen size, processor, memory, graphics, weight, and price.
#
# #### * The objective of this analysis is to extract meaningful insights that can benefit both consumers and manufacturers by understanding how various features influence laptop pricing and market positioning.

# %% [markdown]
# ### 1. Data understanding
# ### 2. Data cleaning
# ### 3. Data Analysis
# ### 4. Recommendations

# %% [markdown]
# # DATA UNDERSTANDING

# %% [markdown]
# ## IMPORT LIBRARIES:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from scipy.stats import ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max.rows",None)
pd.set_option("display.max.columns",None)

# %% [markdown]
# ### LOAD DATASET

# %%
df = pd.read_csv(r"C:\Users\kokil\Downloads\4bdf8c4e-f670-4f18-9d2a-734ec63189db-Reinforcement Project - Python (1)\Reinforcement Project - Python\Laptop Dataset\laptopData.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
df.tail()
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                         Gpu       OpSys  Weight     Price
# 1298  Intel HD Graphics 520  Windows 10   1.8kg  33992.64
# 1299  Intel HD Graphics 520  Windows 10   1.3kg  79866.72
# 1300      Intel HD Graphics  Windows 10   1.5kg  12201.12
# 1301     AMD Radeon R5 M330  Windows 10  2.19kg  40705.92
# 1302      Intel HD Graphics  Windows 10   2.2kg  19660.32

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1253 non-null   object
#  3   Inches            1220 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1259 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1259 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          30
# Company             30
# TypeName            50
# Inches              83
# ScreenResolution    30
# Cpu                 30
# Ram                 44
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              44
# Price               30
# dtype: int64

# %%
#to find the how much percentage of null in every columns
round(df.isnull().sum()/len(df.index)*100,2)
# Out:
# Unnamed: 0          2.30
# Company             2.30
# TypeName            3.84
# Inches              6.37
# ScreenResolution    2.30
# Cpu                 2.30
# Ram                 3.38
# Memory              2.30
# Gpu                 2.30
# OpSys               2.30
# Weight              3.38
# Price               2.30
# dtype: float64

# %% [markdown]
# # DATA CLEANING

# %%
#no.of duplicates
df.duplicated().sum()
# Out:
# np.int64(29)

# %%
#drop duplicates
df.drop_duplicates(inplace=True)

# %%
#display only null value row/columns
df[df.isnull().any(axis=1)]
# Out:
#       Unnamed: 0  Company            TypeName Inches  \
# 18          18.0   Lenovo            Notebook   15.6
# 20           NaN      NaN                 NaN    NaN
# 24          24.0       HP           Ultrabook   15.6
# 67          67.0       HP            Notebook     14
# 75          75.0     Asus              Gaming   15.6
# 111        111.0     Dell           Ultrabook   13.3
# 129        129.0       HP            Notebook   17.3
# 149        149.0     Acer            Notebook   15.6
# 159        159.0  Toshiba            Notebook   15.6
# 189        189.0     Dell            Notebook   17.3
# 244        244.0   Lenovo  2 in 1 Convertible   13.9
# 268        268.0       HP            Notebook   17.3
# 314        314.0     Asus  2 in 1 Convertible   11.6
# 319        319.0     Acer            Notebook   11.6
# 337        337.0       HP            Notebook   15.6
# 348        348.0     Asus  2 in 1 Convertible   11.6
# 378        378.0     Asus            Notebook     14
# 379        379.0     Acer            Notebook   15.6
# 380        380.0       HP              Gaming   17.3
# 381        381.0   Lenovo            Notebook   15.6
# 382        382.0     Asus              Gaming   15.6
# 383        383.0   Lenovo            Notebook     14
# 384        384.0     Asus           Ultrabook   13.3
# 391        391.0     Asus              Gaming   17.3
# 408        408.0   Lenovo            Notebook   35.6
# 469        469.0   Lenovo           Ultrabook     14
# 532        532.0     Asus            Notebook   15.6
# 549        549.0   Lenovo                 NaN   15.6
# 569        569.0   Lenovo                 NaN     14
# 572        572.0       HP            Notebook   15.6
# 609        609.0     Acer                 NaN     14
# 659        659.0     Dell                 NaN   17.3
# 693        693.0   Lenovo                 NaN     14
# 727        727.0     Dell                 NaN   13.3
# 728        728.0     Dell                 NaN   15.6
# 756        756.0       HP                 NaN   15.6
# 803        803.0     Dell            Notebook    NaN
# 809        809.0   Lenovo                 NaN   15.6
# 852        852.0     Dell            Notebook    NaN
# 856        856.0     Asus                 NaN   15.6
# 901        901.0     Asus              Gaming    NaN
# 920        920.0     Dell                 NaN   15.6
# 947        947.0   Lenovo            Notebook    NaN
# 981        981.0  Toshiba                 NaN   13.3
# 982        982.0   Lenovo                 NaN   15.6
# 983        983.0  Fujitsu                 NaN   15.6
# 984        984.0  Toshiba                 NaN     14
# 985        985.0     Dell                 NaN   15.6
# 986        986.0       HP                 NaN   15.6
# 1001      1001.0       HP                 NaN   13.3
# 1002      1002.0     Dell                 NaN   15.6
# 1003      1003.0       HP                 NaN     14
# 1011      1011.0       HP           Ultrabook    NaN
# 1012      1012.0       HP            Notebook    NaN
# 1013      1013.0       HP           Ultrabook    NaN
# 1014      1014.0       HP            Notebook    NaN
# 1015      1015.0  Toshiba            Notebook    NaN
# 1016      1016.0       HP            Notebook    NaN
# 1017      1017.0   Lenovo            Notebook    NaN
# 1018      1018.0  Toshiba            Notebook    NaN
# 1019      1019.0       HP            Notebook    NaN
# 1020      1020.0     Dell  2 in 1 Convertible    NaN
# 1034      1034.0       HP            Notebook    NaN
# 1071      1071.0       HP            Notebook    NaN
# 1072      1072.0       HP           Ultrabook    NaN
# 1073      1073.0       HP            Notebook    NaN
# 1074      1074.0   Lenovo           Ultrabook    NaN
# 1075      1075.0   Lenovo            Notebook    NaN
# 1076      1076.0   Lenovo            Notebook    NaN
# 1077      1077.0      MSI              Gaming    NaN
# 1078      1078.0   Lenovo            Notebook    NaN
# 1079      1079.0       HP            Notebook    NaN
# 1080      1080.0   Lenovo           Ultrabook    NaN
# 1081      1081.0   Lenovo              Gaming    NaN
# 1082      1082.0   Lenovo  2 in 1 Convertible    NaN
# 1083      1083.0       HP           Ultrabook    NaN
# 1084      1084.0     Dell            Notebook    NaN
# 1085      1085.0       HP            Notebook    NaN
# 1086      1086.0       HP         Workstation    NaN
# 1087      1087.0   Lenovo            Notebook    NaN
# 1088      1088.0       HP            Notebook    NaN
# 1089      1089.0     Acer            Notebook    NaN
# 1090      1090.0     Dell            Notebook    NaN
# 1091      1091.0       HP            Notebook    NaN
# 1092      1092.0     Asus              Gaming    NaN
# 1093      1093.0     Dell           Ultrabook    NaN
# 1094      1094.0       HP             Netbook    NaN
# 1095      1095.0     Acer            Notebook    NaN
# 1096      1096.0     Dell            Notebook    NaN
# 1097      1097.0      MSI              Gaming    NaN
# 1098      1098.0       HP            Notebook    NaN
# 1099      1099.0     Asus              Gaming    NaN
# 1100      1100.0     Dell           Ultrabook    NaN
# 1101      1101.0     Dell           Ultrabook    NaN
# 1102      1102.0     Acer            Notebook    NaN
# 1103      1103.0       HP         Workstation    NaN
# 1104      1104.0   Lenovo              Gaming    NaN
# 1211      1211.0     Asus            Notebook    NaN
# 1212      1212.0      MSI              Gaming    NaN
# 1213      1213.0     Dell  2 in 1 Convertible    NaN
# 1214      1214.0     Asus              Gaming    NaN
#
#                                ScreenResolution  \
# 18                            Full HD 1920x1080
# 20                                          NaN
# 24                            Full HD 1920x1080
# 67                                     1366x768
# 75                            Full HD 1920x1080
# 111            Quad HD+ / Touchscreen 3200x1800
# 129                           Full HD 1920x1080
# 149                                    1366x768
# 159                                    1366x768
# 189                           Full HD 1920x1080
# 244   IPS Panel Full HD / Touchscreen 1920x1080
# 268                           Full HD 1920x1080
# 314                        Touchscreen 1366x768
# 319                                    1366x768
# 337                           Full HD 1920x1080
# 348                        Touchscreen 1366x768
# 378                                    1366x768
# 379                           Full HD 1920x1080
# 380                 IPS Panel Full HD 1920x1080
# 381                           Full HD 1920x1080
# 382                 IPS Panel Full HD 1920x1080
# 383                 IPS Panel Full HD 1920x1080
# 384             Full HD / Touchscreen 1920x1080
# 391                           Full HD 1920x1080
# 408                           Full HD 1920x1080
# 469                IPS Panel Quad HD+ 2560x1440
# 532             IPS Panel 4K Ultra HD 3840x2160
# 549                 IPS Panel Full HD 1920x1080
# 149               Intel Core i3 6006U 2GHz   4GB                    1TB HDD
# 159             Intel Core i3 6006U 2.2GHz   NaN                  500GB HDD
# 189             Intel Core i7 8550U 1.8GHz   NaN       128GB SSD +  1TB HDD
# 244             Intel Core i7 7500U 2.7GHz   8GB                  256GB SSD
# 268             Intel Core i7 8550U 1.8GHz   NaN                    1TB HDD
# 314   Intel Celeron Dual Core N3350 1.1GHz   2GB         32GB Flash Storage
# 319   Intel Pentium Quad Core N3710 1.6GHz   NaN        128GB Flash Storage
# 337             Intel Core i5 7200U 2.5GHz   8GB                  256GB SSD
# 348   Intel Celeron Dual Core N3350 1.1GHz   NaN         32GB Flash Storage
# 378   Intel Celeron Dual Core N3350 1.1GHz   NaN         32GB Flash Storage
# 379            Intel Core i7 7700HQ 2.8GHz   8GB                    1TB HDD
# 380            Intel Core i7 7700HQ 2.8GHz   8GB       128GB SSD +  1TB HDD
# 381               Intel Core i3 6006U 2GHz   4GB                  128GB SSD
# 382            Intel Core i7 7700HQ 2.8GHz   8GB       128GB SSD +  1TB HDD
# 383             Intel Core i5 7200U 2.5GHz   8GB                  256GB SSD
# 384             Intel Core i7 7500U 2.7GHz  16GB                  512GB SSD
# 391            Intel Core i7 7700HQ 2.8GHz  16GB       256GB SSD +  1TB HDD
# 408               Intel Core i3 6006U 2GHz   NaN                  500GB HDD
# 469             Intel Core i7 6600U 2.6GHz   NaN                  256GB SSD
# 532             Intel Core i7 7500U 2.7GHz   NaN       256GB SSD +  1TB HDD
# 549             Intel Core i7 7500U 2.7GHz   8GB                  512GB SSD
# 569             Intel Core i5 7200U 2.5GHz   4GB                  500GB HDD
# 572             AMD A9-Series A9-9420 3GHz   NaN                  256GB SSD
# 609   Intel Pentium Quad Core N3710 1.6GHz   4GB        128GB Flash Storage
# 659            Intel Core i7 7700HQ 2.8GHz  32GB       512GB SSD +  1TB HDD
# 693             Intel Core i7 7500U 2.7GHz   8GB                  256GB SSD
# 727             Intel Core i3 7100U 2.4GHz   4GB                    1TB HDD
# 728             Intel Core i5 7200U 2.5GHz   8GB                    1TB HDD
# 756            Intel Core i5 7300HQ 2.5GHz   8GB       128GB SSD +  1TB HDD
# 803            Intel Core i5 7300HQ 2.5GHz   8GB                  256GB SSD
# 809             Intel Core i5 7200U 2.5GHz   4GB                    1TB HDD
# 852             Intel Core i7 7500U 2.7GHz   8GB                    1TB HDD
# 856   Intel Pentium Quad Core N4200 1.1GHz   4GB                    1TB HDD
# 901            Intel Core i7 6820HK 2.7GHz  32GB     256GB SSD +  256GB SSD
# 920             Intel Core i5 7200U 2.5GHz   4GB                    1TB HDD
# 947             Intel Core i7 7500U 2.7GHz   8GB                    1TB HDD
# 981             Intel Core i5 6200U 2.3GHz   4GB                  128GB SSD
# 982            AMD A12-Series 9720P 3.6GHz   6GB                  256GB SSD
# 983             Intel Core i5 6200U 2.3GHz   4GB                  256GB SSD
# 984             Intel Core i5 6200U 2.3GHz   4GB                  500GB HDD
# 985             Intel Core i5 7200U 2.5GHz   4GB                  500GB HDD
# 986             Intel Core i5 7200U 2.5GHz   8GB                    1TB HDD
# 1001            Intel Core i5 7200U 2.5GHz   8GB                  256GB SSD
# 1002            Intel Core i3 7100U 2.4GHz   4GB                  128GB SSD
# 1003            Intel Core i5 7200U 2.5GHz   4GB                  500GB HDD
# 1011            Intel Core i5 7200U 2.5GHz   4GB                  500GB HDD
# 1012            Intel Core i5 7200U 2.5GHz   4GB                  256GB SSD
# 1013            Intel Core i7 6500U 2.5GHz   8GB                  256GB SSD
# 1014            Intel Core i3 7100U 2.4GHz   4GB                  500GB HDD
# 1015            Intel Core i5 6200U 2.3GHz   8GB                  256GB SSD
# 1016            Intel Core i3 7100U 2.4GHz   4GB                  256GB SSD
# 1017           Intel Core i7 6820HQ 2.7GHz  16GB                  512GB SSD
# 1018            Intel Core i5 6200U 2.3GHz   8GB                  256GB SSD
# 1019            Intel Core i7 6500U 2.5GHz   8GB                  256GB SSD
# 1020            Intel Core i3 6100U 2.3GHz   4GB                    1TB HDD
# 1034            Intel Core i7 6500U 2.5GHz   8GB                  256GB SSD
# 1071            Intel Core i5 6200U 2.3GHz   4GB                  500GB HDD
# 1072            Intel Core i5 6200U 2.3GHz   8GB                  256GB SSD
# 1073            Intel Core i7 7500U 2.7GHz   8GB                  256GB SSD
# 1074            Intel Core i7 6500U 2.5GHz   8GB                  256GB SSD
# 1075            Intel Core i5 6200U 2.3GHz   8GB                  1.0TB HDD
# 1076           Intel Core i5 6300HQ 2.3GHz   4GB                    1TB HDD
# 1077           Intel Core i7 7700HQ 2.8GHz  16GB       256GB SSD +  1TB HDD
# 1078            Intel Core i5 6200U 2.3GHz   4GB                  500GB HDD
# 1079            Intel Core i5 6200U 2.3GHz   4GB                  500GB HDD
# 1080              Intel Core M 6Y75 1.2GHz   8GB                  512GB SSD
# 1081           Intel Core i7 6820HK 2.7GHz  32GB  512GB SSD +  1.0TB Hybrid
# 1082           Intel Atom x5-Z8550 1.44GHz   4GB         64GB Flash Storage
# 1083            Intel Core i7 7500U 2.7GHz  16GB                  512GB SSD
# 1084            Intel Core i5 7200U 2.5GHz   8GB                  256GB SSD
# 1085            Intel Core i5 6200U 2.3GHz   4GB                  500GB HDD
# 1086            Intel Core i7 6500U 2.5GHz   8GB                  256GB SSD
# 1087            Intel Core i5 6200U 2.3GHz   8GB                  180GB SSD
# 1088  Intel Pentium Dual Core 4405Y 1.5GHz   4GB         32GB Flash Storage
# 1089             AMD A8-Series 7410 2.2GHz   4GB                  500GB HDD
# 1090  Intel Pentium Quad Core N3700 1.6GHz   4GB                  500GB HDD
# 1091              Intel Core i3 6006U 2GHz   4GB                    1TB HDD
# 1092           Intel Core i7 7700HQ 2.8GHz   8GB       256GB SSD +  1TB HDD
# 1093            Intel Core i5 8250U 1.6GHz   4GB                  256GB SSD
# 1094            Intel Core i5 6200U 2.3GHz   4GB                  128GB SSD
# 1095            Intel Core i5 7200U 2.5GHz   8GB       256GB SSD +  1TB HDD
# 1096            Intel Core i5 7200U 2.5GHz   8GB                    1TB HDD
# 1097           Intel Core i7 6700HQ 2.6GHz   8GB                  256GB SSD
# 1098  Intel Pentium Quad Core N3710 1.6GHz   4GB                    1TB HDD
# 1099           Intel Core i7 6700HQ 2.6GHz  16GB       128GB SSD +  1TB HDD
# 1100            Intel Core i3 6100U 2.3GHz   4GB                  500GB HDD
# 1101            Intel Core i3 6100U 2.3GHz   4GB                  128GB SSD
# 1102  Intel Celeron Dual Core 3205U 1.5GHz   4GB                   16GB SSD
# 1103           Intel Core i7 6700HQ 2.6GHz   8GB                    1TB HDD
# 1104           Intel Core i7 7700HQ 2.8GHz  16GB                  512GB SSD
# 1211           Intel Core i7 7700HQ 2.8GHz  16GB       128GB SSD +  1TB HDD
# 1212           Intel Core i7 6700HQ 2.6GHz  16GB       256GB SSD +  1TB HDD
# 1213            Intel Core i5 7200U 2.5GHz   8GB                  256GB SSD
# 1214           Intel Core i7 7700HQ 2.8GHz  16GB       256GB SSD +  1TB HDD
#
#                                Gpu       OpSys   Weight        Price
# 18            Nvidia GeForce 940MX       No OS      NaN   26586.7200
# 20                             NaN         NaN      NaN          NaN
# 24           Intel HD Graphics 620  Windows 10   1.91kg   35111.5200
# 67           Intel HD Graphics 400  Windows 10      NaN   12201.1200
# 75         Nvidia GeForce GTX 1050  Windows 10    2.2kg   50562.7200
# 111   Intel Iris Plus Graphics 640  Windows 10   1.23kg   73473.1200
# 129         Intel UHD Graphics 620  Windows 10    2.5kg   49443.8400
# 149          Intel HD Graphics 520  Windows 10      NaN   23816.1600
# 159          Intel HD Graphics 520  Windows 10    2.1kg   23816.1600
# 189                 AMD Radeon 530  Windows 10    2.8kg   57808.8000
# 244          Intel HD Graphics 620  Windows 10      NaN   57489.1200
# 268          Nvidia GeForce 930MX   Windows 10    2.5kg   54239.0400
# 314          Intel HD Graphics 500  Windows 10      NaN   14652.0000
# 319          Intel HD Graphics 405  Windows 10    1.4kg   25840.8000
# 337          Intel HD Graphics 620  Windows 10      NaN   60952.3200
# 348          Intel HD Graphics 500  Windows 10    1.5kg   19980.0000
# 378          Intel HD Graphics 500  Windows 10      NaN   15238.0800
# 379        Nvidia GeForce GTX 1050       Linux      NaN   45074.8800
# 380        Nvidia GeForce GTX 1050  Windows 10      NaN   63456.4800
# 381          Intel HD Graphics 520       No OS      NaN   21498.4800
# 382        Nvidia GeForce GTX 1060  Windows 10      NaN   88178.4000
# 383           Nvidia GeForce 940MX  Windows 10      NaN   58554.7200
# 384          Intel HD Graphics 620  Windows 10      NaN   93181.3920
# 391     Nvidia GeForce GTX 1050 Ti  Windows 10      NaN   84768.4800
# 408          Intel HD Graphics 520  Windows 10   22.1kg   21791.5200
# 469          Intel HD Graphics 520  Windows 10    1.4kg   98994.2400
# 532        Nvidia GeForce GTX 960M  Windows 10      2kg   69210.7200
# 549          Intel HD Graphics 620  Windows 10   1.99kg   92121.1200
# 569          Intel HD Graphics 620  Windows 10   2.02kg   52747.2000
# 572                 AMD Radeon 530  Windows 10   1.95kg   34578.7200
# 1081       Nvidia GeForce GTX 980M  Windows 10    4.6kg  172627.2000
# 1082         Intel HD Graphics 400  Windows 10   0.69kg   34433.2656
# 1083         Intel HD Graphics 620  Windows 10    1.3kg  109170.7200
# 1084         Intel HD Graphics 620  Windows 10   2.18kg   39960.0000
# 1085         Intel HD Graphics 520   Windows 7   1.54kg   54931.1472
# 1086            AMD FirePro W4190M   Windows 7    1.9kg   79653.6000
# 1087         Intel HD Graphics 520   Windows 7    1.7kg   63882.7200
# 1088         Intel HD Graphics 515   Chrome OS   1.29kg   32767.2000
# 1089                 AMD Radeon R5  Windows 10    2.4kg   20619.3600
# 1090             Intel HD Graphics       Linux    2.2kg   20965.1472
# 1091         Intel HD Graphics 520       No OS   1.86kg   18434.3472
# 1092       Nvidia GeForce GTX 1060  Windows 10    2.7kg   85194.7200
# 1093                AMD Radeon 530  Windows 10    1.4kg   43601.6880
# 1094         Intel HD Graphics 520   Windows 7    2.4kg   85194.7200
# 1095       Nvidia GeForce GTX 950M  Windows 10    2.4kg   42570.7200
# 1096            AMD Radeon R7 M445  Windows 10   2.36kg   34035.2640
# 1097       Nvidia GeForce GTX 965M  Windows 10    2.6kg   85194.7200
# 1098         Intel HD Graphics 405  Windows 10   1.96kg   26640.0000
# 1099       Nvidia GeForce GTX 980M  Windows 10    4.3kg  122490.7200
# 1100         Intel HD Graphics 520   Windows 7    1.5kg   60480.7920
# 1101         Intel HD Graphics 520   Windows 7    1.5kg   62176.1616
# 1102             Intel HD Graphics   Chrome OS   2.20kg   11135.5200
# 1103            AMD FirePro W6150M   Windows 7    3.0kg  154458.7200
# 1104    Nvidia GeForce GTX 1050 Ti  Windows 10    2.4kg   63882.7200
# 1211       Nvidia GeForce GTX 1060  Windows 10    2.2kg   93186.7200
# 1212       Nvidia GeForce GTX 1060  Windows 10   2.43kg  103842.1872
# 1213         Intel HD Graphics 620  Windows 10  2.191kg   53226.7200
# 1214       Nvidia GeForce GTX 1060  Windows 10    2.9kg  103842.7200

# %%
#drop rows which every cell/column has a null
df.dropna(how = "all",inplace=True)

# %%
round(df.isnull().sum()/len(df.index)*100,2)
# Out:
# Unnamed: 0          2.30
# Company             2.30
# TypeName            3.84
# Inches              6.37
# ScreenResolution    2.30
# Cpu                 2.30
# Ram                 3.38
# Memory              2.30
# Gpu                 2.30
# OpSys               2.30
# Weight              3.38
# Price               2.30
# dtype: float64

# %%
#dropped the Unnamed: 0 column
df.drop(["Unnamed: 0"],axis=1,inplace = True)

# %%
df["Company"].value_counts()
# Out:
# Company
# Lenovo       290
# Dell         287
# HP           266
# Asus         156
# Acer         103
# MSI           53
# Toshiba       47
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# LG             3
# Google         3
# Huawei         2
# Fujitsu        2
# Name: count, dtype: int64

# %%
#fill null values with unknown
df["TypeName"].fillna("unknown",inplace=True)

# %%
df["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              693
# Gaming                202
# Ultrabook             191
# 2 in 1 Convertible    114
# unknown                50
# Workstation            29
# Netbook                24
# Name: count, dtype: int64

# %%
#rerplace "Netbook" as "Notebook"
df["TypeName"] = df["TypeName"].replace("Netbook","Notebook")

# %%
df["TypeName"].value_counts()
# Out:
# TypeName
# Notebook              717
# Gaming                202
# Ultrabook             191
# 2 in 1 Convertible    114
# unknown                50
# Workstation            29
# Name: count, dtype: int64

# %%
df["Inches"].value_counts()
# Out:
# Inches
# 15.6     615
# 14       184
# 13.3     155
# 17.3     148
# 12.5      31
# 11.6      31
# 12         6
# 13.9       6
# 13.5       5
# 12.3       5
# 15.4       4
# 15         4
# 35.6       3
# 24         2
# 13         2
# 10.1       2
# 18.4       1
# 27.3       1
# 25.6       1
# 31.6       1
# 33.5       1
# 17         1
# 14.1       1
# 11.3       1
# ?          1
# 88.1       1
# 21.8       1
# 75.7       1
# 8.4        1
# 2.1        1
# 111.8      1
# 89.2       1
# 65.4       1
# Name: count, dtype: int64

# %%
#repplace "?" with 0
df["Inches"].replace("?","0",inplace=True)

# %%
#fill null values with 0
df["Inches"] = df["Inches"].fillna(0)

# %%
#convert Inches as float datatype
df["Inches"] = df["Inches"].astype(float)

# %%
#find mean for inches between 13-17.3
inch_filter_df = df[(df["Inches"] > 13) & (df["Inches"] < 17.3)]
print(inch_filter_df["Inches"].mean())
avg_inch = round(inch_filter_df["Inches"].mean(),2)
# Out:
# 14.90779487179487

# %%
#changed the find mean values with unreal values
df["Inches"] = df["Inches"].where((df["Inches"] > 13) & (df["Inches"] < 17.3), avg_inch)

# %%
df["Inches"].value_counts()
# Out:
# Inches
# 15.60    615
# 14.91    298
# 14.00    184
# 13.30    155
# 13.90      6
# 13.50      5
# 15.40      4
# 15.00      4
# 17.00      1
# 14.10      1
# Name: count, dtype: int64

# %%
df["Weight"].value_counts()
# Out:
# Weight
# 2.2kg        109
# 2.1kg         55
# 2.4kg         42
# 2.3kg         40
# 2.5kg         37
# 2kg           32
# 2.8kg         27
# 1.2kg         25
# 1.4kg         23
# 2.04kg        22
# 1.86kg        22
# 2.18kg        22
# 1.6kg         20
# 1.5kg         19
# 1.95kg        18
# 1.9kg         18
# 1.7kg         17
# 1.8kg         17
# 1.3kg         17
# 1.91kg        14
# 1.26kg        13
# 1.36kg        13
# 1.37kg        13
# 3kg           13
# 1.25kg        12
# 1.1kg         12
# 2.7kg         12
# 2.62kg        12
# 2.6kg         12
# 1.63kg        11
# 4.42kg        11
# 1.29kg        11
# 1.48kg        10
# 2.0kg         10
# 1.49kg        10
# 2.65kg         9
# 2.23kg         9
# 1.64kg         9
# 1.84kg         9
# 2.36kg         8
# 2.31kg         8
# 2.9kg          8
# 1.54kg         8
# 2.06kg         8
# 1.23kg         7
# 1.45kg         7
# 2.02kg         7
# 1.05kg         7
# 3.2kg          7
# 1.65kg         7
# 1.32kg         7
# 1.44kg         7
# 2.19kg         6
# 1.34kg         6
# 1.88kg         6
# 1.62kg         6
# 1.75kg         6
# 1.28kg         6
# 1.42kg         6
# 1.43kg         6
# 2.25kg         6
# 1.47kg         5
# 1.93kg         5
# 3.78kg         5
# 1.21kg         5
# 2.05kg         5
# 1.96kg         5
# 1.35kg         5
# 2.32kg         5
# 2.20kg         5
# 1.17kg         5
# 1.16kg         5
# 1.13kg         5
# 0.920kg        4
# 2.09kg         4
# 2.59kg         4
# 4.6kg          4
# 2.63kg         4
# 4.36kg         4
# 1.24kg         4
# 2.08kg         4
# 2.37kg         4
# 4.3kg          4
# 2.24kg         4
# 1.252kg        4
# 2.56kg         4
# 1.22kg         4
# 2.43kg         4
# 1.83kg         4
# 2.71kg         3
# 2.77kg         3
# 1.98kg         3
# 1.99kg         3
# 1.15kg         3
# 2.33kg         3
# 1.85kg         3
# 1.90kg         3
# 1.38kg         3
# 1.56kg         3
# 1.58kg         3
# 3.14kg         3
# 4.2kg          3
# 1.87kg         3
# 3.21kg         3
# 1.68kg         3
# 3.35kg         3
# 0.69kg         3
# 2.73kg         3
# 2.67kg         3
# 3.49kg         3
# 2.17kg         3
# 2.13kg         2
# 1.89kg         2
# 0.92kg         2
# 2.45kg         2
# 2.16kg         2
# 0.81kg         2
# 2.07kg         2
# 2.94kg         2
# 1.74kg         2
# 0.97kg         2
# 7.2kg          2
# 2.15kg         2
# 1.78kg         2
# 2.14kg         2
# 4.14kg         2
# 1.76kg         2
# 1.71kg         2
# 3.31kg         2
# 3.58kg         2
# 1.27kg         2
# 2.69kg         2
# 2.29kg         2
# 1.09kg         2
# 3.0kg          2
# 1.08kg         2
# 3.3kg          2
# 1.11kg         2
# 2.03kg         1
# 4.4kg          1
# 5.4kg          1
# 4.33kg         1
# 9kg            1
# 0.91kg         1
# 22.1kg         1
# 3.25kg         1
# 1.79kg         1
# 5.8kg          1
# 4.7kg          1
# 3.6kg          1
# 1.12kg         1
# 1.41kg         1
# 4.1kg          1
# ?              1
# 0.00008kg      1
# 1.10kg         1
# 0.0002kg       1
# 8.23kg         1
# 2.79kg         1
# 2.26kg         1
# 11.5Kg         1
# 2.54kg         1
# 3.42kg         1
# 4.5kg          1
# 1.55kg         1
# 29kg           1
# 1.14kg         1
# 11.1kg         1
# 6.2kg          1
# 3.8kg          1
# 1.19kg         1
# 1.39kg         1
# 8.4kg          1
# 1.94kg         1
# 10kg           1
# 3.4kg          1
# 14kg           1
# 3.74kg         1
# 2.72kg         1
# 18kg           1
# 0.98kg         1
# 2.38kg         1
# 2.83kg         1
# 1.18kg         1
# 1.31kg         1
# 1.70kg         1
# 2.99kg         1
# 2.75kg         1
# 0.99kg         1
# 4kg            1
# 2.591kg        1
# 3.52kg         1
# 2.21kg         1
# 2.191kg        1
# 2.34kg         1
# 4.0kg          1
# Name: count, dtype: int64

# %%
#can't able to convert datatype to float due to "?" and that has been found by query
df.query("Weight == '?'")
# Out:
#     Company   TypeName  Inches   ScreenResolution                         Cpu  \
# 208    Dell  Ultrabook    13.3  Full HD 1920x1080  Intel Core i7 8550U 1.8GHz
#
#      Ram     Memory                     Gpu       OpSys Weight     Price
# 208  8GB  256GB SSD  Intel UHD Graphics 620  Windows 10      ?  77202.72

# %%
#replaced that "?" into 0
df["Weight"].replace("?",0,inplace = True)

# %%
#converted that datatype to string and then cutted-off "kg"
df["Weight"] = df["Weight"].str.replace("kg","")

# %%
df["Weight"] = df["Weight"].str.replace("Kg","")

# %%
#converted datatype string to float after removal of "kg".Due to find the mean value and change the unreal data
df["Weight"] = df["Weight"].astype(float)

# %%
df["Weight"].value_counts()
# Out:
# Weight
# 2.20000     114
# 2.10000      55
# 2.00000      42
# 2.40000      42
# 2.30000      40
# 2.50000      37
# 2.80000      27
# 1.20000      25
# 1.40000      23
# 2.04000      22
# 1.86000      22
# 2.18000      22
# 1.90000      21
# 1.60000      20
# 1.50000      19
# 1.95000      18
# 1.70000      18
# 1.80000      17
# 1.30000      17
# 3.00000      15
# 1.91000      14
# 1.37000      13
# 1.36000      13
# 1.10000      13
# 1.26000      13
# 2.62000      12
# 2.70000      12
# 2.60000      12
# 1.25000      12
# 1.29000      11
# 4.42000      11
# 1.63000      11
# 1.49000      10
# 1.48000      10
# 1.64000       9
# 1.84000       9
# 2.23000       9
# 2.65000       9
# 2.36000       8
# 2.31000       8
# 1.54000       8
# 2.06000       8
# 2.90000       8
# 1.45000       7
# 1.23000       7
# 1.44000       7
# 3.20000       7
# 1.65000       7
# 2.02000       7
# 1.32000       7
# 1.05000       7
# 1.34000       6
# 0.92000       6
# 1.62000       6
# 1.88000       6
# 1.28000       6
# 2.25000       6
# 2.19000       6
# 1.75000       6
# 1.42000       6
# 1.43000       6
# 1.35000       5
# 1.96000       5
# 1.21000       5
# 2.05000       5
# 1.16000       5
# 1.13000       5
# 3.78000       5
# 2.32000       5
# 1.93000       5
# 1.47000       5
# 1.17000       5
# 2.43000       4
# 2.56000       4
# 1.83000       4
# 2.63000       4
# 4.60000       4
# 1.24000       4
# 2.59000       4
# 2.24000       4
# 2.09000       4
# 4.36000       4
# 2.37000       4
# 1.22000       4
# 4.30000       4
# 2.08000       4
# 1.25200       4
# 2.77000       3
# 2.71000       3
# 1.85000       3
# 1.58000       3
# 3.14000       3
# 1.99000       3
# 3.21000       3
# 2.73000       3
# 1.98000       3
# 1.56000       3
# 1.38000       3
# 1.87000       3
# 1.15000       3
# 3.49000       3
# 2.33000       3
# 2.17000       3
# 1.68000       3
# 3.35000       3
# 0.69000       3
# 4.20000       3
# 2.67000       3
# 7.20000       2
# 0.97000       2
# 2.45000       2
# 2.13000       2
# 1.89000       2
# 2.16000       2
# 2.15000       2
# 2.69000       2
# 2.14000       2
# 4.14000       2
# 1.74000       2
# 1.71000       2
# 2.07000       2
# 1.78000       2
# 1.27000       2
# 2.94000       2
# 0.81000       2
# 1.11000       2
# 1.76000       2
# 4.00000       2
# 1.08000       2
# 3.30000       2
# 3.58000       2
# 3.31000       2
# 2.29000       2
# 1.09000       2
# 22.10000      1
# 1.79000       1
# 11.50000      1
# 0.00008       1
# 4.10000       1
# 1.12000       1
# 2.03000       1
# 5.40000       1
# 4.40000       1
# 0.00020       1
# 8.23000       1
# 2.26000       1
# 3.25000       1
# 5.80000       1
# 3.42000       1
# 2.54000       1
# 2.79000       1
# 1.41000       1
# 3.60000       1
# 4.70000       1
# 8.40000       1
# 1.19000       1
# 29.00000      1
# 6.20000       1
# 3.80000       1
# 1.39000       1
# 11.10000      1
# 1.14000       1
# 9.00000       1
# 10.00000      1
# 0.91000       1
# 4.33000       1
# 3.40000       1
# 1.94000       1
# 14.00000      1
# 4.50000       1
# 2.72000       1
# 2.38000       1
# 2.83000       1
# 18.00000      1
# 3.74000       1
# 1.31000       1
# 1.55000       1
# 1.18000       1
# 0.98000       1
# 2.99000       1
# 2.75000       1
# 3.52000       1
# 0.99000       1
# 2.59100       1
# 2.21000       1
# 2.19100       1
# 2.34000       1
# Name: count, dtype: int64

# %%
#find the mean value for weight between 1-4.5
weight_filter_df = df[(df["Weight"] > 1) & (df["Weight"] < 4.5)]
print(weight_filter_df["Weight"].mean())
avg_weight = round(weight_filter_df["Weight"].mean(),2)
# Out:
# 2.048433141919606

# %%
#changed the find mean values with unreal values
df["Weight"] = df["Weight"].where((df["Weight"] > 1) & (df["Weight"] < 4.5), avg_weight)

# %%
#rounded the float with .1 to undedrstand better
df["Weight"] = round(df["Weight"],1)

# %%
df["Weight"].value_counts()
# Out:
# Weight
# 2.2    170
# 2.0    160
# 1.4     85
# 2.1     77
# 1.9     74
# 1.2     72
# 1.3     67
# 2.4     61
# 2.3     60
# 1.6     60
# 1.5     52
# 2.6     46
# 1.8     44
# 2.5     38
# 2.8     33
# 1.1     26
# 1.7     25
# 2.7     24
# 4.4     16
# 3.0     16
# 3.2     11
# 2.9     10
# 1.0      7
# 3.8      6
# 4.3      5
# 3.4      5
# 3.3      4
# 3.5      4
# 3.6      3
# 4.1      3
# 3.1      3
# 4.2      3
# 4.0      2
# 3.7      1
# Name: count, dtype: int64

# %%
#find the mean value for weight between 1-4.5
weight_filter_df = df[(df["Weight"] > 1) & (df["Weight"] < 4.5)]
print(weight_filter_df["Weight"].mean())
avg_weight = round(weight_filter_df["Weight"].mean(),2)
# Out:
# 2.051421800947867

# %%
#changed the find mean values with unreal values
df["Weight"] = df["Weight"].where((df["Weight"] > 1) & (df["Weight"] < 4.5), avg_weight)

# %%
#rounded the float with .1 to undedrstand better
df["Weight"] = round(df["Weight"],1)

# %%
df["Weight"]
# Out:
# 0       1.4
# 1       1.3
# 2       1.9
# 3       1.8
# 4       1.4
# 5       2.1
# 6       2.0
# 7       1.3
# 8       1.3
# 9       1.6
# 10      1.9
# 11      1.9
# 12      1.8
# 13      2.2
# 14      2.0
# 15      1.4
# 16      2.2
# 17      1.8
# 18      2.0
# 19      1.2
# 21      2.5
# 22      1.9
# 23      1.6
# 24      1.9
# 25      2.3
# 26      1.4
# 27      2.2
# 28      1.9
# 29      2.5
# 30      1.9
# 31      1.6
# 32      2.7
# 33      1.2
# 34      1.4
# 35      1.4
# 36      2.1
# 37      2.8
# 38      1.9
# 39      2.1
# 40      2.0
# 1204    2.2
# 1205    2.4
# 1206    1.9
# 1207    2.2
# 1208    3.3
# 1209    2.2
# 1210    2.0
# 1211    2.2
# 1212    2.4
# 1213    2.2
# 1214    2.9
# 1215    1.3
# 1216    3.3
# 1217    2.8
# 1218    2.6
# 1219    1.2
# 1220    2.3
# 1221    2.2
# 1222    2.1
# 1223    1.3
# 1224    2.1
# 1225    2.6
# 1226    1.3
# 1227    2.2
# 1228    2.6
# 1229    2.2
# 1230    1.3
# 1231    2.0
# 1232    2.3
# 1233    2.7
# 1234    1.1
# 1235    2.1
# 1236    1.5
# 1237    2.2
# 1238    2.3
# 1239    1.4
# 1240    2.2
# 1241    1.4
# 1242    2.4
# 1243    2.8
# 1244    1.5
# 1246    1.6
# 1247    2.3
# 1248    2.3
# 1249    1.2
# 1250    2.2
# 1251    1.9
# 1252    2.4
# 1253    1.9
# 1254    2.2
# 1255    2.0
# 1256    4.0
# 1257    2.3
# 1258    2.3
# 1259    2.4
# 1260    1.8
# 1261    1.2
# 1262    2.3
# 1263    2.4
# 1264    2.2
# 1265    2.6
# 1266    2.0
# 1267    2.3
# 1268    1.2
# 1269    2.2
# 1270    1.8
# 1271    1.3
# 1272    1.5
# 1273    2.2
# 1274    2.2
# 1275    1.2
# 1276    2.3
# 1277    2.4
# 1278    2.2
# 1279    2.6
# 1280    2.0
# 1281    2.3
# 1282    1.2
# 1283    2.2
# 1284    1.8
# 1285    1.3
# 1286    1.5
# 1287    2.2
# 1288    2.2
# 1289    1.2
# 1290    2.3
# 1291    2.4
# 1292    2.2
# 1293    2.6
# 1294    2.0
# 1295    2.3
# 1296    1.2
# 1297    2.2
# 1298    1.8
# 1299    1.3
# 1300    1.5
# 1301    2.2
# 1302    2.2
# Name: Weight, dtype: float64

# %%
#string datatype so mode has beed found
ram_mode = df["Ram"].mode()

# %%
ram_mode
# Out:
# 0    8GB
# Name: Ram, dtype: object

# %%
#filled the null value with mode of RAM
df["Ram"] = df["Ram"].fillna(ram_mode[0])

# %%
#string datatype so mode has beed found
memory_mode = df["Memory"].mode()

# %%
memory_mode
# Out:
# 0    256GB SSD
# Name: Memory, dtype: object

# %%
#"?" has been found which is the only one has no value, so using replace it changed with the mode value
df["Memory"] = df["Memory"].replace("?",memory_mode[0])

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256GB SSD                        402
# 1TB HDD                          217
# 500GB HDD                        130
# 512GB SSD                        116
# 128GB SSD +  1TB HDD              92
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              71
# 32GB Flash Storage                37
# 2TB HDD                           16
# 64GB Flash Storage                14
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           13
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 128GB Flash Storage                4
# 180GB SSD                          4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 64GB SSD                           1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 512GB SSD +  256GB SSD             1
# 32GB HDD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             63
# Linux             61
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: count, dtype: int64

# %%
#In the OpSys column, the value "NO OS" is not relevant, so I decided to replace it with the most frequent value (mode). 
#Before doing that, I filtered for Apple segment laptops and confirmed that "NO OS" does not appear in that segment. 
#Since the company sells both Apple and Windows laptops, and "NO OS" appears only in non-Apple entries, I replaced "NO OS" with "Windows 10".


df["OpSys"].replace("No OS","Windows 10",inplace=True)

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1110
# Linux             61
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: count, dtype: int64

# %%
#Converted the Price column to integer type for better readability and cleaner value presentation
df["Price"] = pd.to_numeric(df["Price"], errors="coerce").fillna(0).astype(int)

# %%
df.columns.to_list()
# Out:
# ['Company',
#  'TypeName',
#  'Inches',
#  'ScreenResolution',
#  'Cpu',
#  'Ram',
#  'Memory',
#  'Gpu',
#  'OpSys',
#  'Weight',
#  'Price']

# %%
#renamed the column name
df.rename(columns = {'Company' : "Company",
 'TypeName' : "Type_Name",
 'Inches' : "Screen_Size(Inch)",
 'ScreenResolution' : "Screen_Resolution",
 'Cpu' : "Processor",
 'Ram' : "RAM",
 'Memory' : "Memory",
 'Gpu' : "GPU",
 'OpSys' : "OpSys",
 'Weight' : "Weight(Kg)",
 'Price' : "Price"},inplace=True)

# %%
df.isnull().sum()
# Out:
# Company              0
# Type_Name            0
# Screen_Size(Inch)    0
# Screen_Resolution    0
# Processor            0
# RAM                  0
# Memory               0
# GPU                  0
# OpSys                0
# Weight(Kg)           0
# Price                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1273 non-null   object
#  1   Type_Name          1273 non-null   object
#  2   Screen_Size(Inch)  1273 non-null   float64
#  3   Screen_Resolution  1273 non-null   object
#  4   Processor          1273 non-null   object
#  5   RAM                1273 non-null   object
#  6   Memory             1273 non-null   object
#  7   GPU                1273 non-null   object
#  8   OpSys              1273 non-null   object
#  9   Weight(Kg)         1273 non-null   float64
#  10  Price              1273 non-null   int64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 119.3+ KB

# %%
df.head()
# Out:
#   Company  Type_Name  Screen_Size(Inch)                   Screen_Resolution  \
# 0   Apple  Ultrabook               13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook               13.3                            1440x900
# 2      HP   Notebook               15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook               15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook               13.3  IPS Panel Retina Display 2560x1600
#
#                     Processor   RAM               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             GPU       OpSys  Weight(Kg)   Price
# 0  Intel Iris Plus Graphics 640       macOS         1.4   71378
# 1        Intel HD Graphics 6000       macOS         1.3   47895
# 2         Intel HD Graphics 620  Windows 10         1.9   30636
# 3            AMD Radeon Pro 455       macOS         1.8  135195
# 4  Intel Iris Plus Graphics 650       macOS         1.4   96095

# %%
#created the function for setting the new column for segment laptops
def category_preference(Price):
    if Price <=45000:
        return "Entry-Level"
    elif Price <=75000:
        return "Mainstream / Mid-Range"
    else:
        return "Premium / High-End"

df["Preference"] = df["Price"].apply(category_preference)

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1110
# Linux             61
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            1
# Name: count, dtype: int64

# %%
df["RAM(GB)"] = df["RAM"].str.replace("GB", "").astype(int)

# %%
#created function for categories the apple & window laptops
def laptop_brand(OpSys):
    if "macOS" in OpSys or "Mac OS X" in OpSys:
        return "Mac"
    elif "Windows" in OpSys:
        return "Windows"
    elif "Linux" in OpSys:
        return "Linux"
    elif "Chrome" in OpSys:
        return "Chrome OS"
    elif "Android" in OpSys:
        return "Android"
    else:
        return "Other"

df["OS_Type"] = df["OpSys"].apply(laptop_brand)

# %%
#created function for CPU standarsize
def cpu_standardize(Processor):
    if "Intel" in Processor:
        return "Intel"
    elif "AMD" in Processor:
        return "AMD"
    else:
        return "Others"

df["Processor_Type"] = df["Processor"].apply(cpu_standardize)

# %%
#created function for GPU standardize
def gpu_standardize(g):
    g = str(g).lower()

    if "integrated" in g or "intel" in g or "vega" in g:
        return "Integrated"
    else:
        return "Dedicated"

df["GPU_Type"] = df["GPU"].apply(gpu_standardize)

# %%
def weight_category(Weight):
    if Weight <= 2.0:
        return "Light"
    elif Weight <= 3.5:
        return "Moderate"
    else:
        return "Heavy"

df["Weight_Category"] = df["Weight(Kg)"].apply(weight_category)

# %%
df
# Out:
#         Company           Type_Name  Screen_Size(Inch)  \
# 0         Apple           Ultrabook              13.30
# 1         Apple           Ultrabook              13.30
# 2            HP            Notebook              15.60
# 3         Apple           Ultrabook              15.40
# 4         Apple           Ultrabook              13.30
# 5          Acer            Notebook              15.60
# 6         Apple           Ultrabook              15.40
# 7         Apple           Ultrabook              13.30
# 8          Asus           Ultrabook              14.00
# 9          Acer           Ultrabook              14.00
# 10           HP            Notebook              15.60
# 11           HP            Notebook              15.60
# 12        Apple           Ultrabook              15.40
# 13         Dell            Notebook              15.60
# 14        Apple           Ultrabook              14.91
# 15        Apple           Ultrabook              13.30
# 16         Dell            Notebook              15.60
# 17        Apple           Ultrabook              15.40
# 18       Lenovo            Notebook              15.60
# 19         Dell           Ultrabook              13.30
# 21       Lenovo              Gaming              15.60
# 22           HP            Notebook              15.60
# 23         Dell  2 in 1 Convertible              13.30
# 24           HP           Ultrabook              15.60
# 25         Dell            Notebook              15.60
# 26        Apple           Ultrabook              13.30
# 27         Dell            Notebook              15.60
# 28         Dell           Ultrabook              15.60
# 29           HP            Notebook              14.91
# 30        Chuwi            Notebook              15.60
# 31         Asus            Notebook              14.00
# 32           HP            Notebook              14.91
# 33         Dell           Ultrabook              13.30
# 34        Apple           Ultrabook              13.30
# 35       Lenovo            Notebook              14.00
# 36         Acer            Notebook              15.60
# 37         Dell            Notebook              14.91
# 38           HP            Notebook              15.60
# 39           HP            Notebook              15.60
# 40         Asus            Notebook              15.60
# 41         Dell              Gaming              15.60
# 42         Asus            Notebook              15.60
# 43         Acer            Notebook              15.60
# 44         Dell  2 in 1 Convertible              14.91
# 45        Apple           Ultrabook              13.30
# 47         Asus              Gaming              14.91
# 48         Dell            Notebook              15.60
# 49         Asus            Notebook              14.91
# 51         Acer            Notebook              15.60
# 52           HP            Notebook              15.60
# 53           HP            Notebook              13.30
# 54         Acer            Notebook              15.60
# 55         Dell            Notebook              15.60
# 56           HP            Notebook              15.60
# 57         Asus            Notebook              15.60
# 58          MSI              Gaming              14.91
# 59         Asus            Notebook              15.60
# 60         Dell            Notebook              14.91
# 61         Dell           Ultrabook              14.00
# 62       Lenovo            Notebook              14.00
# 63         Asus            Notebook              14.00
# 64           HP            Notebook              15.60
# 65         Asus           Ultrabook              15.60
# 66           HP            Notebook              15.60
# 67           HP            Notebook              14.00
# 68       Lenovo            Notebook              15.60
# 69         Asus              Gaming              14.91
# 70    Microsoft           Ultrabook              13.50
# 71         Dell           Ultrabook              13.30
# 72         Dell            Notebook              15.60
# 73          MSI              Gaming              14.91
# 74         Acer            Notebook              14.00
# 75         Asus              Gaming              15.60
# 76       Lenovo            Notebook              15.60
# 77         Dell            Notebook              15.60
# 78         Acer            Notebook              15.60
# 79           HP            Notebook              14.91
# 80         Dell           Ultrabook              15.60
# 81        Apple           Ultrabook              14.91
# 82           HP            Notebook              14.00
# 83       Lenovo            Notebook              15.60
# 84         Acer            Notebook              15.60
# 85         Dell              Gaming              15.60
# 86           HP           Ultrabook              15.60
# 87           HP            Notebook              15.60
# 88         Asus              Gaming              15.60
# 89         Dell           Ultrabook              13.30
# 90         Asus              Gaming              15.60
# 91         Acer            Notebook              15.60
# 92           HP            Notebook              13.30
# 93         Dell              Gaming              15.60
# 94         Asus           Ultrabook              14.00
# 95         Acer  2 in 1 Convertible              13.30
# 96         Dell            Notebook              15.60
# 97         Dell            Notebook              15.60
# 98         Asus            Notebook              15.60
# 99           HP              Gaming              15.60
# 100          HP            Notebook              15.60
# 101          HP            Notebook              15.60
# 102        Dell            Notebook              15.60
# 103          HP           Ultrabook              13.30
# 104   Microsoft           Ultrabook              13.50
# 105          HP            Notebook              14.00
# 106      Lenovo            Notebook              15.60
# 107        Asus           Ultrabook              14.00
# 108         MSI              Gaming              15.60
# 109      Lenovo            Notebook              14.00
# 110        Asus           Ultrabook              15.60
# 111        Dell           Ultrabook              13.30
# 112      Lenovo  2 in 1 Convertible              13.30
# 113          HP            Notebook              14.00
# 114        Dell           Ultrabook              13.30
# 116          HP            Notebook              14.00
# 117        Dell            Notebook              15.60
# 118        Asus            Notebook              14.91
# 119        Asus            Notebook              15.60
# 120        Acer            Notebook              15.60
# 121         MSI              Gaming              15.60
# 122      Lenovo            Notebook              15.60
# 123          HP            Notebook              14.91
# 124        Acer            Notebook              15.60
# 126          HP            Notebook              14.00
# 127        Asus            Notebook              14.00
# 128        Dell            Notebook              14.91
# 129          HP            Notebook              14.91
# 130        Dell            Notebook              15.60
# 131        Dell            Notebook              15.60
# 132        Acer           Ultrabook              14.00
# 133        Acer            Notebook              15.60
# 134          HP            Notebook              15.60
# 135          HP            Notebook              14.00
# 136      Lenovo            Notebook              15.60
# 137        Asus              Gaming              14.91
# 138      Lenovo            Notebook              15.60
# 139          HP            Notebook              13.30
# 140        Acer            Notebook              14.91
# 141      Lenovo            Notebook              14.00
# 142      Lenovo              Gaming              15.60
# 143     Toshiba            Notebook              15.60
# 144          HP            Notebook              15.60
# 145        Asus           Ultrabook              14.00
# 146          HP           Ultrabook              14.91
# 147        Asus            Notebook              15.60
# 149        Acer            Notebook              15.60
# 150        Dell              Gaming              15.60
# 151        Dell              Gaming              15.60
# 152      Lenovo            Notebook              15.60
# 153         MSI              Gaming              14.91
# 154          HP           Ultrabook              14.00
# 155          HP            Notebook              15.60
# 156      Lenovo  2 in 1 Convertible              14.00
# 157        Asus  2 in 1 Convertible              13.30
# 158        Dell  2 in 1 Convertible              15.60
# 159     Toshiba            Notebook              15.60
# 160        Asus            Notebook              15.60
# 161        Acer            Notebook              14.91
# 162        Dell            Notebook              15.60
# 163      Lenovo              Gaming              15.60
# 164        Acer            Notebook              15.60
# 165         MSI              Gaming              15.60
# 166        Acer            Notebook              15.60
# 167        Dell              Gaming              15.60
# 168        Acer            Notebook              14.91
# 169          HP            Notebook              13.30
# 170      Huawei           Ultrabook              14.91
# 171          HP            Notebook              14.91
# 172      Lenovo            Notebook              15.60
# 173     Toshiba            Notebook              15.60
# 174          HP            Notebook              14.91
# 175        Dell            Notebook              15.60
# 176        Acer            Notebook              15.60
# 177         MSI              Gaming              14.91
# 178      Lenovo            Notebook              15.60
# 179          HP  2 in 1 Convertible              13.30
# 180        Dell            Notebook              15.60
# 181        Dell           Ultrabook              13.30
# 182      Lenovo  2 in 1 Convertible              13.90
# 183     Toshiba            Notebook              15.60
# 184      Xiaomi            Notebook              15.60
# 185        Dell            Notebook              14.91
# 186        Dell            Notebook              15.60
# 187      Lenovo              Gaming              15.60
# 188        Acer           Ultrabook              13.30
# 189        Dell            Notebook              14.91
# 191        Vero            Notebook              14.00
# 192      Xiaomi           Ultrabook              13.30
# 193      Lenovo            Notebook              14.91
# 194        Dell  2 in 1 Convertible              13.30
# 195          HP            Notebook              14.91
# 196       Razer              Gaming              14.91
# 197          HP            Notebook              13.30
# 198          HP              Gaming              14.91
# 199          HP            Notebook              14.91
# 200        Dell              Gaming              15.60
# 201      Lenovo            Notebook              15.60
# 202        Acer            Notebook              15.60
# 203      Lenovo              Gaming              15.60
# 204        Dell         Workstation              15.60
# 205      Lenovo              Gaming              15.60
# 206        Dell            Notebook              15.60
# 207        Dell           Ultrabook              13.30
# 208        Dell           Ultrabook              13.30
# 210        Acer            Notebook              15.60
# 211        Asus              Gaming              14.91
# 212          HP            Notebook              15.60
# 213      Lenovo            Notebook              15.60
# 214      Huawei           Ultrabook              14.91
# 215        Dell           Ultrabook              13.30
# 216      Lenovo            Notebook              14.91
# 217          HP            Notebook              14.00
# 218        Dell           Ultrabook              14.00
# 219        Dell  2 in 1 Convertible              13.30
# 220        Dell            Notebook              15.60
# 221      Lenovo  2 in 1 Convertible              14.00
# 222     Toshiba           Ultrabook              13.30
# 223          HP            Notebook              15.60
# 224        Dell              Gaming              14.91
# 225        Acer            Notebook              15.60
# 226        Dell            Notebook              15.60
# 227        Asus            Notebook              15.60
# 228        Asus            Notebook              14.91
# 229          HP            Notebook              15.60
# 230        Asus            Notebook              15.60
# 231          HP            Notebook              15.60
# 232      Lenovo              Gaming              15.60
# 233        Dell            Notebook              14.00
# 234        Acer  2 in 1 Convertible              13.30
# 235        Dell            Notebook              15.60
# 236        Acer            Notebook              15.60
# 237        Asus            Notebook              15.60
# 238        Asus              Gaming              14.91
# 239        Acer              Gaming              15.60
# 240      Lenovo            Notebook              15.60
# 241        Asus            Notebook              14.91
# 242        Asus            Notebook              14.91
# 243        Dell              Gaming              15.60
# 244      Lenovo  2 in 1 Convertible              13.90
# 245        Dell            Notebook              15.60
# 246          HP            Notebook              15.60
# 247        Asus              Gaming              14.91
# 248          HP            Notebook              13.30
# 249       Apple           Ultrabook              13.30
# 250        Dell  2 in 1 Convertible              15.60
# 251        Asus              Gaming              14.91
# 252        Asus            Notebook              15.60
# 253      Lenovo  2 in 1 Convertible              13.90
# 254        Acer            Notebook              14.91
# 255        Dell           Ultrabook              13.30
# 256          HP            Notebook              15.60
# 257          HP            Notebook              14.91
# 258         MSI              Gaming              14.91
# 259      Lenovo  2 in 1 Convertible              15.60
# 260        Dell            Notebook              14.91
# 261      Lenovo            Notebook              15.60
# 262          HP            Notebook              15.60
# 263        Dell            Notebook              15.60
# 264        Dell            Notebook              15.60
# 265        Dell  2 in 1 Convertible              15.60
# 266        Asus  2 in 1 Convertible              13.30
# 268          HP            Notebook              14.91
# 269      Lenovo            Notebook              15.60
# 270       Apple           Ultrabook              13.30
# 271        Asus              Gaming              14.91
# 272        Dell            Notebook              15.60
# 273      Lenovo  2 in 1 Convertible              14.00
# 274     Toshiba            Notebook              15.60
# 275        Dell            Notebook              15.60
# 276        Dell            Notebook              14.91
# 277        Acer            Notebook              15.60
# 278      Lenovo            Notebook              14.91
# 279      Lenovo            Notebook              14.91
# 280      Lenovo            Notebook              14.91
# 281        Dell            Notebook              15.60
# 282      Lenovo              Gaming              15.60
# 283      Lenovo            Notebook              15.60
# 284        Acer            Notebook              15.60
# 285        Acer            Notebook              15.60
# 286      Lenovo            Notebook              15.60
# 287        Asus           Ultrabook              15.60
# 288      Lenovo              Gaming              15.60
# 289      Lenovo            Notebook              15.60
# 290        Acer            Notebook              15.60
# 291        Asus              Gaming              14.91
# 292          HP            Notebook              14.91
# 293        Dell            Notebook              15.60
# 294      Lenovo            Notebook              15.60
# 295      Lenovo              Gaming              15.60
# 296        Acer            Notebook              15.60
# 297        Dell         Workstation              14.91
# 298      Lenovo            Notebook              15.60
# 299        Asus           Ultrabook              15.60
# 300        Asus            Notebook              14.00
# 301        Asus              Gaming              14.91
# 302      Lenovo            Notebook              14.91
# 303      Lenovo            Notebook              15.60
# 304        Asus              Gaming              15.60
# 305      Lenovo            Notebook              15.60
# 306          HP  2 in 1 Convertible              13.30
# 307     Toshiba            Notebook              15.60
# 308      Lenovo            Notebook              15.60
# 309          HP            Notebook              15.60
# 310      Lenovo            Notebook              13.30
# 311        Dell           Ultrabook              13.30
# 312         MSI              Gaming              15.60
# 313        Acer            Notebook              15.60
# 314        Asus  2 in 1 Convertible              14.91
# 315        Dell            Notebook              15.60
# 316          HP  2 in 1 Convertible              13.30
# 317      Lenovo            Notebook              13.30
# 318          HP            Notebook              14.00
# 319        Acer            Notebook              14.91
# 320          HP            Notebook              14.00
# 321      Lenovo            Notebook              14.91
# 322        Asus            Notebook              14.00
# 323          HP            Notebook              15.60
# 324        Acer            Notebook              15.60
# 325      Lenovo            Notebook              14.00
# 326        Acer            Notebook              15.60
# 327        Asus           Ultrabook              15.60
# 328          HP           Ultrabook              14.91
# 329        Dell            Notebook              15.60
# 330         MSI              Gaming              14.91
# 331     Toshiba            Notebook              15.60
# 332        Asus            Notebook              14.00
# 333      Lenovo            Notebook              15.60
# 334        Asus              Gaming              15.60
# 335          HP            Notebook              14.00
# 337          HP            Notebook              15.60
# 338        Asus            Notebook              15.60
# 339        Dell            Notebook              15.60
# 340        Dell            Notebook              15.60
# 341      Lenovo            Notebook              15.60
# 342          HP            Notebook              15.60
# 343      Lenovo  2 in 1 Convertible              13.90
# 344        Dell           Ultrabook              13.30
# 345      Lenovo              Gaming              15.60
# 346          HP            Notebook              14.00
# 347        Dell           Ultrabook              15.60
# 348        Asus  2 in 1 Convertible              14.91
# 349        Dell           Ultrabook              15.60
# 351          HP            Notebook              15.60
# 352         MSI              Gaming              14.91
# 353          HP         Workstation              15.60
# 354     Toshiba            Notebook              15.60
# 355        Dell            Notebook              15.60
# 356      Lenovo            Notebook              15.60
# 357        Dell              Gaming              15.60
# 358        Dell            Notebook              15.60
# 359        Dell            Notebook              14.00
# 360          HP            Notebook              15.60
# 361        Asus            Notebook              14.00
# 362      Lenovo            Notebook              14.91
# 363          HP            Notebook              15.60
# 364      Lenovo            Notebook              15.60
# 365          HP            Notebook              15.60
# 366        Dell            Notebook              14.91
# 367      Lenovo              Gaming              15.60
# 368        Dell            Notebook              15.60
# 369          HP           Ultrabook              14.00
# 370        Asus  2 in 1 Convertible              15.60
# 371        Acer            Notebook              15.60
# 372        Asus              Gaming              14.91
# 373      Lenovo            Notebook              14.91
# 374        Dell  2 in 1 Convertible              13.30
# 375          HP            Notebook              15.60
# 376      Lenovo             Netbook              14.91
# 377        Dell            Notebook              15.60
# 378        Asus            Notebook              14.00
# 379        Acer            Notebook              15.60
# 380          HP              Gaming              14.91
# 381      Lenovo            Notebook              15.60
# 382        Asus              Gaming              15.60
# 383      Lenovo            Notebook              14.00
# 384        Asus           Ultrabook              13.30
# 385      Lenovo           Ultrabook              14.00
# 386      Lenovo            Notebook              13.30
# 387        Dell         Workstation              15.60
# 388        Dell         Workstation              15.60
# 389      Lenovo  2 in 1 Convertible              14.00
# 390        Asus              Gaming              14.91
# 391        Asus              Gaming              14.91
# 392        Acer            Notebook              15.60
# 393         MSI              Gaming              14.91
# 394        Dell            Notebook              15.60
# 395          HP           Ultrabook              15.60
# 396      Lenovo            Notebook              15.60
# 397      Lenovo            Notebook              14.00
# 398        Dell         Workstation              15.60
# 399      Lenovo           Ultrabook              14.00
# 400      Lenovo            Notebook              15.60
# 401        Asus              Gaming              14.91
# 402      Lenovo            Notebook              14.91
# 403        Acer            Notebook              15.60
# 404         MSI              Gaming              14.91
# 405        Asus           Ultrabook              14.00
# 406     Toshiba           Ultrabook              13.30
# 407        Dell           Ultrabook              14.00
# 408      Lenovo            Notebook              14.91
# 409      Lenovo            Notebook              14.91
# 410      Lenovo         Workstation              15.60
# 411      Lenovo           Ultrabook              14.00
# 412          HP            Notebook              15.60
# 413        Acer  2 in 1 Convertible              13.30
# 414        Asus  2 in 1 Convertible              13.30
# 415        Dell            Notebook              15.60
# 416        Dell            Notebook              13.30
# 417          HP           Ultrabook              14.00
# 418        Dell            Notebook              15.60
# 419      Lenovo           Ultrabook              14.00
# 420      Lenovo  2 in 1 Convertible              15.60
# 421       Chuwi            Notebook              14.91
# 422          HP            Notebook              15.60
# 423        Asus            Notebook              14.91
# 424        Dell              Gaming              14.91
# 425        Dell              Gaming              15.60
# 426        Dell            Notebook              15.60
# 427        Dell           Ultrabook              14.00
# 428          HP              Gaming              14.91
# 429    Mediacom  2 in 1 Convertible              14.91
# 430     Samsung             Netbook              14.91
# 431      Lenovo            Notebook              13.30
# 432      Lenovo            Notebook              14.00
# 433      Lenovo         Workstation              15.60
# 434      Lenovo            Notebook              15.60
# 435        Asus              Gaming              14.91
# 436          HP            Notebook              15.60
# 437      Google           Ultrabook              14.91
# 438      Lenovo           Ultrabook              14.91
# 439        Asus            Notebook              15.60
# 440      Lenovo            Notebook              14.91
# 441        Dell            Notebook              15.60
# 442      Lenovo           Ultrabook              14.91
# 443      Lenovo            Notebook              15.60
# 444          HP              Gaming              15.60
# 445        Dell            Notebook              14.00
# 446        Acer            Notebook              15.60
# 447        Dell         Workstation              15.60
# 448         MSI              Gaming              15.60
# 449   Microsoft           Ultrabook              13.50
# 450          HP            Notebook              15.60
# 451        Dell         Workstation              15.60
# 452          HP         Workstation              15.60
# 453      Lenovo            Notebook              14.00
# 454        Dell            Notebook              15.60
# 455        Dell  2 in 1 Convertible              14.91
# 456        Dell            Notebook              14.91
# 457   Microsoft           Ultrabook              13.50
# 458   Microsoft           Ultrabook              14.91
# 459          HP            Notebook              14.91
# 460        Acer            Notebook              15.60
# 461        Acer             Netbook              14.91
# 462        Asus            Notebook              15.60
# 463      Lenovo            Notebook              14.00
# 464      Lenovo            Notebook              15.60
# 465        Asus            Notebook              15.60
# 466        Acer            Notebook              15.60
# 467        Dell            Notebook              15.60
# 468          HP              Gaming              14.91
# 469      Lenovo           Ultrabook              14.00
# 470          HP  2 in 1 Convertible              13.30
# 471          HP            Notebook              15.60
# 472      Google           Ultrabook              14.91
# 473        Dell           Ultrabook              13.30
# 474        Asus            Notebook              15.60
# 475        Dell            Notebook              14.00
# 476        Dell         Workstation              14.91
# 477      Lenovo            Notebook              14.00
# 479     Toshiba            Notebook              13.30
# 480        Dell            Notebook              15.60
# 481        Dell            Notebook              15.60
# 482          HP            Notebook              13.30
# 483       Chuwi            Notebook              15.60
# 484      Lenovo            Notebook              15.60
# 485      Lenovo            Notebook              14.00
# 486        Dell         Workstation              15.60
# 487        Dell            Notebook              15.60
# 488      Lenovo           Ultrabook              14.91
# 489        Asus           Ultrabook              14.91
# 490      Lenovo            Notebook              15.60
# 491     Toshiba           Ultrabook              13.30
# 492        Asus              Gaming              15.60
# 493        Acer            Notebook              15.60
# 494        Asus              Gaming              14.91
# 495      Lenovo           Ultrabook              14.91
# 496      Lenovo            Notebook              15.60
# 497          HP            Notebook              14.00
# 498      Lenovo            Notebook              13.30
# 499      Lenovo            Notebook              15.60
# 500        Asus             Netbook              14.91
# 501          HP            Notebook              15.60
# 502      Lenovo  2 in 1 Convertible              13.90
# 503      Lenovo            Notebook              14.00
# 504      Lenovo             Netbook              14.91
# 505      Lenovo            Notebook              13.30
# 506        Asus            Notebook              15.60
# 507        Acer            Notebook              15.60
# 508          HP           Ultrabook              13.30
# 509      Lenovo              Gaming              15.60
# 510        Dell           Ultrabook              13.30
# 511        Acer            Notebook              15.60
# 512        Dell            Notebook              15.60
# 513        Dell            Notebook              15.60
# 514      Xiaomi            Notebook              15.60
# 515        Asus             Netbook              14.91
# 516          HP            Notebook              15.60
# 517        Asus              Gaming              15.60
# 518          HP            Notebook              15.60
# 519        Asus              Gaming              14.91
# 520      Lenovo              Gaming              15.60
# 521          HP           Ultrabook              13.30
# 522        Dell            Notebook              14.00
# 523          HP            Notebook              15.60
# 524        Dell            Notebook              14.91
# 525      Lenovo            Notebook              14.91
# 526      Lenovo            Notebook              15.60
# 527      Lenovo            Notebook              15.60
# 528        Dell            Notebook              15.60
# 529        Dell            Notebook              15.60
# 530        Dell              Gaming              14.91
# 531     Toshiba            Notebook              15.60
# 532        Asus            Notebook              15.60
# 533    Mediacom            Notebook              13.30
# 534        Asus              Gaming              15.60
# 535        Dell            Notebook              15.60
# 536        Dell            Notebook              15.60
# 537          HP            Notebook              15.60
# 538          HP              Gaming              14.91
# 539      Lenovo            Notebook              14.00
# 540        Dell           Ultrabook              13.30
# 541        Dell            Notebook              14.00
# 542          HP           Ultrabook              13.30
# 543        Acer              Gaming              15.60
# 544        Asus            Notebook              15.60
# 545          HP            Notebook              15.60
# 546      Lenovo            Notebook              14.00
# 547      Lenovo            Notebook              15.60
# 548          HP            Notebook              15.60
# 549      Lenovo             unknown              15.60
# 550      Lenovo            Notebook              15.60
# 551        Dell            Notebook              15.60
# 552        Dell              Gaming              14.91
# 553          HP            Notebook              14.91
# 554          HP            Notebook              14.91
# 555        Asus            Notebook              15.60
# 556    Mediacom            Notebook              13.30
# 557      Lenovo            Notebook              14.91
# 558          HP            Notebook              15.60
# 559        Dell            Notebook              15.60
# 560        Acer  2 in 1 Convertible              14.91
# 561      Lenovo            Notebook              15.60
# 562          HP           Ultrabook              13.30
# 563      Lenovo            Notebook              14.91
# 564        Asus            Notebook              15.60
# 565        Dell           Ultrabook              13.30
# 566        Dell            Notebook              15.60
# 568      Lenovo            Notebook              15.60
# 569      Lenovo             unknown              14.00
# 570          HP         Workstation              14.91
# 571          HP            Notebook              14.00
# 572          HP            Notebook              15.60
# 573      Lenovo            Notebook              15.60
# 574      Lenovo            Notebook              15.60
# 575    Mediacom            Notebook              14.00
# 576     Toshiba           Ultrabook              14.00
# 577      Lenovo              Gaming              14.91
# 578         MSI              Gaming              14.91
# 579        Dell            Notebook              15.60
# 580    Mediacom            Notebook              14.00
# 581        Dell            Notebook              15.60
# 582          HP            Notebook              13.30
# 583        Dell            Notebook              15.60
# 584        Dell             Netbook              14.91
# 585         MSI              Gaming              14.91
# 586          HP              Gaming              14.91
# 587      Lenovo           Ultrabook              14.00
# 588      Lenovo            Notebook              15.60
# 589        Asus              Gaming              14.91
# 590        Asus  2 in 1 Convertible              15.60
# 591      Lenovo            Notebook              15.60
# 592        Dell  2 in 1 Convertible              14.91
# 593     Samsung            Notebook              15.60
# 594      Lenovo            Notebook              14.91
# 595      Lenovo            Notebook              15.60
# 596      Lenovo  2 in 1 Convertible              13.30
# 597      Lenovo            Notebook              14.00
# 598        Dell  2 in 1 Convertible              14.91
# 599        Dell         Workstation              15.60
# 600          HP            Notebook              15.60
# 601          HP            Notebook              15.60
# 602        Acer            Notebook              14.00
# 603         MSI              Gaming              14.91
# 604        Dell            Notebook              15.60
# 605         MSI              Gaming              15.60
# 606     Toshiba            Notebook              15.60
# 607      Lenovo            Notebook              15.60
# 608      Lenovo  2 in 1 Convertible              15.60
# 609        Acer             unknown              14.00
# 610      Lenovo            Notebook              15.60
# 611        Dell              Gaming              15.60
# 612        Dell            Notebook              15.60
# 613        Dell            Notebook              15.60
# 614        Dell            Notebook              15.60
# 615        Asus              Gaming              14.91
# 617          HP           Ultrabook              15.60
# 618         MSI              Gaming              15.60
# 619        Acer  2 in 1 Convertible              14.91
# 620          HP            Notebook              14.00
# 621      Lenovo            Notebook              14.00
# 622        Dell            Notebook              15.60
# 623     Fujitsu            Notebook              15.60
# 624          HP            Notebook              15.60
# 626    Mediacom            Notebook              14.00
# 627      Lenovo            Notebook              15.60
# 628        Asus  2 in 1 Convertible              13.30
# 630        Asus           Ultrabook              14.00
# 631        Dell              Gaming              15.60
# 632      Lenovo            Notebook              15.60
# 633      Lenovo            Notebook              15.60
# 634        Asus            Notebook              15.60
# 635        Asus            Notebook              15.60
# 636        Dell           Ultrabook              13.30
# 637      Lenovo            Notebook              14.00
# 638      Lenovo  2 in 1 Convertible              13.30
# 639        Dell            Notebook              15.60
# 640      Lenovo              Gaming              15.60
# 641          HP            Notebook              17.00
# 642      Lenovo           Ultrabook              14.00
# 643        Asus              Gaming              15.60
# 644        Acer            Notebook              15.60
# 645      Lenovo            Notebook              14.00
# 646        Acer           Ultrabook              14.00
# 647       Razer              Gaming              14.00
# 648     Toshiba            Notebook              13.30
# 649      Lenovo           Ultrabook              14.91
# 650        Asus              Gaming              14.91
# 651        Acer              Gaming              15.60
# 652        Dell           Ultrabook              13.30
# 653         MSI              Gaming              15.60
# 654          HP            Notebook              15.60
# 655     Toshiba            Notebook              15.60
# 656        Dell            Notebook              15.60
# 657        Dell            Notebook              15.60
# 658      Lenovo              Gaming              15.60
# 659        Dell             unknown              14.91
# 660        Dell            Notebook              14.00
# 661      Lenovo            Notebook              15.60
# 662      Lenovo            Notebook              15.60
# 663          HP            Notebook              15.60
# 664         MSI              Gaming              14.91
# 665     Toshiba            Notebook              15.60
# 667          HP            Notebook              15.60
# 668     Toshiba            Notebook              15.60
# 669        Acer            Notebook              15.60
# 670   Microsoft           Ultrabook              13.50
# 671      Lenovo            Notebook              15.60
# 672      Lenovo  2 in 1 Convertible              13.30
# 673      Lenovo            Notebook              14.91
# 674          HP  2 in 1 Convertible              14.00
# 675         MSI              Gaming              15.60
# 676        Asus           Ultrabook              14.00
# 677          HP  2 in 1 Convertible              14.91
# 678          LG           Ultrabook              15.60
# 679        Acer              Gaming              15.60
# 680         MSI              Gaming              15.60
# 681        Asus            Notebook              15.60
# 682        Dell              Gaming              15.60
# 683          HP            Notebook              14.91
# 684      Lenovo  2 in 1 Convertible              13.30
# 685        Dell              Gaming              15.60
# 686          HP            Notebook              15.60
# 687        Dell            Notebook              15.60
# 688          HP            Notebook              14.91
# 689      Lenovo            Notebook              15.60
# 690        Acer            Notebook              14.00
# 691      Lenovo            Notebook              14.00
# 692          HP         Workstation              14.91
# 693      Lenovo             unknown              14.00
# 694     Toshiba            Notebook              13.30
# 695        Acer             Netbook              14.91
# 696      Lenovo  2 in 1 Convertible              14.00
# 697        Asus  2 in 1 Convertible              14.91
# 698     Toshiba           Ultrabook              13.30
# 700        Dell              Gaming              15.60
# 701      Lenovo            Notebook              15.60
# 702      Lenovo            Notebook              15.60
# 703      Lenovo            Notebook              15.60
# 704      Lenovo            Notebook              15.60
# 705        Dell            Notebook              15.60
# 706        Acer  2 in 1 Convertible              13.30
# 707      Lenovo         Workstation              15.60
# 708      Lenovo            Notebook              14.00
# 709          HP            Notebook              14.91
# 710      Lenovo              Gaming              15.60
# 711        Dell            Notebook              14.00
# 712        Dell            Notebook              15.60
# 713        Asus            Notebook              14.00
# 714        Dell            Notebook              15.60
# 715      Lenovo            Notebook              14.00
# 716        Dell            Notebook              15.60
# 717      Lenovo            Notebook              15.60
# 718    Mediacom            Notebook              14.00
# 719          HP            Notebook              14.91
# 720      Lenovo           Ultrabook              14.00
# 721          HP  2 in 1 Convertible              13.30
# 722      Lenovo           Ultrabook              14.00
# 723        Dell              Gaming              14.91
# 724         MSI              Gaming              14.91
# 725      Lenovo            Notebook              15.60
# 727        Dell             unknown              13.30
# 728        Dell             unknown              15.60
# 729          HP            Notebook              15.60
# 730        Acer              Gaming              14.91
# 731        Dell            Notebook              15.60
# 732          HP            Notebook              15.60
# 733        Acer            Notebook              15.60
# 734      Lenovo            Notebook              13.30
# 735      Lenovo            Notebook              15.60
# 736          HP         Workstation              15.60
# 737        Dell  2 in 1 Convertible              13.30
# 738         MSI              Gaming              15.60
# 739        Acer            Notebook              15.60
# 740        Dell            Notebook              15.60
# 741        Dell            Notebook              15.60
# 742     Toshiba            Notebook              14.00
# 743      Lenovo  2 in 1 Convertible              14.00
# 744      Lenovo         Workstation              15.60
# 745        Acer            Notebook              14.00
# 746     Samsung           Ultrabook              13.30
# 748        Dell            Notebook              14.00
# 749          HP         Workstation              14.91
# 750      Lenovo             Netbook              14.91
# 751          HP            Notebook              15.60
# 752        Asus            Notebook              15.60
# 754        Asus            Notebook              15.60
# 755      Lenovo  2 in 1 Convertible              13.30
# 756          HP             unknown              15.60
# 757          HP         Workstation              15.60
# 758        Dell              Gaming              15.60
# 759        Acer            Notebook              15.60
# 760      Lenovo              Gaming              15.60
# 761        Dell           Ultrabook              14.91
# 762      Google           Ultrabook              14.91
# 763        Asus           Ultrabook              13.30
# 764        Dell            Notebook              13.30
# 765        Acer            Notebook              13.30
# 766        Asus            Notebook              14.91
# 767        Dell              Gaming              15.60
# 768     Samsung           Ultrabook              13.30
# 769        Acer            Notebook              15.60
# 770        Dell            Notebook              15.60
# 771     Samsung  2 in 1 Convertible              15.00
# 772     Toshiba            Notebook              14.00
# 773        Dell              Gaming              15.60
# 775        Asus  2 in 1 Convertible              15.60
# 776      Lenovo            Notebook              15.60
# 777        Acer            Notebook              14.00
# 778       Razer              Gaming              14.00
# 779        Asus            Notebook              15.60
# 780        Dell              Gaming              14.91
# 781        Asus              Gaming              14.91
# 782     Toshiba           Ultrabook              14.00
# 783      Lenovo            Notebook              15.60
# 784      Lenovo           Ultrabook              14.00
# 785         MSI              Gaming              14.00
# 786         MSI              Gaming              15.60
# 787      Lenovo              Gaming              15.60
# 788        Acer              Gaming              14.91
# 789        Dell              Gaming              15.60
# 790        Asus              Gaming              15.60
# 791        Vero            Notebook              14.00
# 792      Lenovo  2 in 1 Convertible              13.30
# 793      Lenovo  2 in 1 Convertible              15.60
# 794       Apple           Ultrabook              14.91
# 795      Lenovo  2 in 1 Convertible              14.00
# 796        Asus            Notebook              14.00
# 797        Dell            Notebook              15.60
# 798      Lenovo  2 in 1 Convertible              13.90
# 799        Dell            Notebook              15.60
# 800          HP         Workstation              15.60
# 801        Asus            Notebook              15.60
# 802        Dell           Ultrabook              13.30
# 803        Dell            Notebook              14.91
# 804        Dell             Netbook              14.91
# 805          HP             Netbook              14.91
# 806     Toshiba            Notebook              15.60
# 807          HP            Notebook              15.60
# 808        Dell              Gaming              15.60
# 809      Lenovo             unknown              15.60
# 810          HP              Gaming              14.91
# 811         MSI              Gaming              14.91
# 812     Samsung           Ultrabook              13.30
# 813        Dell            Notebook              15.60
# 814        Dell            Notebook              15.60
# 815      Lenovo           Ultrabook              14.00
# 816       Razer           Ultrabook              14.91
# 817          HP             Netbook              14.91
# 818        Dell              Gaming              14.91
# 819        Dell            Notebook              14.00
# 820      Lenovo            Notebook              15.60
# 821     Toshiba           Ultrabook              14.00
# 822      Lenovo           Ultrabook              14.00
# 823         MSI              Gaming              15.60
# 824      Lenovo           Ultrabook              14.00
# 825     Toshiba            Notebook              14.00
# 826        Asus  2 in 1 Convertible              13.30
# 827        Dell            Notebook              14.00
# 828        Acer             Netbook              14.91
# 829        Acer            Notebook              14.00
# 830       Razer              Gaming              14.91
# 831      Lenovo           Ultrabook              14.00
# 832        Asus            Notebook              15.60
# 833      Lenovo            Notebook              14.00
# 834      Lenovo            Notebook              14.00
# 835        Dell              Gaming              15.60
# 836        Asus              Gaming              14.91
# 837     Toshiba            Notebook              15.60
# 838      Lenovo            Notebook              14.00
# 839        Asus            Notebook              15.60
# 840        Asus              Gaming              14.91
# 841        Dell              Gaming              14.91
# 842          HP            Notebook              14.91
# 843        Dell            Notebook              15.60
# 844          HP           Ultrabook              14.00
# 845        Dell            Notebook              15.60
# 846          HP  2 in 1 Convertible              14.91
# 847        Asus           Ultrabook              13.30
# ...
# 395     Windows
# 396     Windows
# 397     Windows
# 398     Windows
# 399     Windows
# 400     Windows
# 401     Windows
# 402     Windows
# 403       Linux
# 404     Windows
# 405     Windows
# 406     Windows
# 407     Windows
# 408     Windows
# 409     Windows
# 410     Windows
# 411     Windows
# 412     Windows
# 413     Windows
# 414     Windows
# 415       Linux
# 416     Windows
# 417     Windows
# 418     Windows
# 419     Windows
# 420     Windows
# 421     Windows
# 422     Windows
# 423       Linux
# 424     Windows
# 425     Windows
# 426     Windows
# 427       Linux
# 428     Windows
# 429     Windows
# 430   Chrome OS
# 431     Windows
# 432     Windows
# 433     Windows
# 434     Windows
# 435     Windows
# 436     Windows
# 437   Chrome OS
# 438     Windows
# 439       Linux
# 440     Windows
# 441     Windows
# 442     Windows
# 443     Windows
# 444     Windows
# 445     Windows
# 446       Linux
# 447     Windows
# 448     Windows
# 449     Windows
# 450     Windows
# 451     Windows
# 452     Windows
# 453     Windows
# 454     Windows
# 455     Windows
# 456     Windows
# 457     Windows
# 458     Windows
# 459     Windows
# 460     Windows
# 461     Windows
# 462     Windows
# 463     Windows
# 464     Windows
# 465     Windows
# 466     Windows
# 467     Windows
# 468     Windows
# 469     Windows
# 470     Windows
# 471     Windows
# 472   Chrome OS
# 473     Windows
# 474     Windows
# 475     Windows
# 476     Windows
# 477     Windows
# 479     Windows
# 480     Windows
# 481     Windows
# 482     Windows
# 483     Windows
# 484     Windows
# 485     Windows
# 486     Windows
# 487     Windows
# 488     Windows
# 489     Windows
# 490     Windows
# 491     Windows
# 492     Windows
# 493     Windows
# 494     Windows
# 495     Windows
# 496     Windows
# 497     Windows
# 498     Windows
# 499     Windows
# 500     Windows
# 501     Windows
# 502     Windows
# 503     Windows
# 504   Chrome OS
# 505     Windows
# 506     Windows
# 507     Windows
# 508     Windows
# 509     Windows
# 510     Windows
# 511     Windows
# 512     Windows
# 513     Windows
# 514     Windows
# 515     Windows
# 516     Windows
# 517     Windows
# 518     Windows
# 519     Windows
# 520     Windows
# 521     Windows
# 522     Windows
# 523     Windows
# 524       Linux
# 525     Windows
# 526     Windows
# 527     Windows
# 528     Windows
# 529     Windows
# 530     Windows
# 531     Windows
# 532     Windows
# 533     Windows
# 534     Windows
# 535     Windows
# 536     Windows
# 537     Windows
# 538     Windows
# 539     Windows
# 540     Windows
# 541     Windows
# 542     Windows
# 543       Linux
# 544     Windows
# 545     Windows
# 546     Windows
# 547     Windows
# 548     Windows
# 549     Windows
# 550     Windows
# 551     Windows
# 552     Windows
# 553     Windows
# 554     Windows
# 555       Linux
# 556     Windows
# 557     Windows
# 558     Windows
# 559     Windows
# 560     Windows
# 561     Windows
# 562     Windows
# 563     Windows
# 564     Windows
# 565     Windows
# 566     Windows
# 568     Windows
# 569     Windows
# 570     Windows
# 571     Windows
# 572     Windows
# 573     Windows
# 574     Windows
# 575     Windows
# 576     Windows
# 577     Windows
# 578     Windows
# 579       Linux
# 580     Windows
# 581     Windows
# 582     Windows
# 583     Windows
# 584   Chrome OS
# 585     Windows
# 586     Windows
# 587     Windows
# 588     Windows
# 589     Windows
# 590     Windows
# 591     Windows
# 592     Windows
# 593     Windows
# 594     Windows
# 595     Windows
# 596     Windows
# 597     Windows
# 598     Windows
# 599     Windows
# 600     Windows
# 601     Windows
# 602     Windows
# 603     Windows
# 604       Linux
# 605     Windows
# 606     Windows
# 607     Windows
# 608     Windows
# 609     Windows
# 610     Windows
# 611     Windows
# 612       Linux
# 613       Linux
# 614       Linux
# 615     Windows
# 617     Windows
# 618     Windows
# 619   Chrome OS
# 620     Windows
# 621     Windows
# 622     Windows
# 623     Windows
# 624     Windows
# 626     Windows
# 627     Windows
# 628     Windows
# 630     Windows
# 631     Windows
# 632     Windows
# 633     Windows
# 634     Windows
# 635     Windows
# 636     Windows
# 637     Windows
# 638     Windows
# 639     Windows
# 640     Windows
# 641     Windows
# 642     Windows
# 643     Windows
# 644     Windows
# 645     Windows
# 646     Windows
# 647     Windows
# 648     Windows
# 649     Windows
# 650     Windows
# 651       Linux
# 652     Windows
# 653     Windows
# 654     Windows
# 655     Windows
# 656     Windows
# 657     Windows
# 658     Windows
# 659     Windows
# 660     Windows
# 661     Windows
# 662     Windows
# 663     Windows
# 664     Windows
# 665     Windows
# 667     Windows
# 668     Windows
# 669       Linux
# 670     Windows
# 671     Windows
# 672     Windows
# 673     Windows
# 674     Windows
# 675     Windows
# 676     Windows
# 677   Chrome OS
# 678     Windows
# 679     Windows
# 680     Windows
# 681     Windows
# 682     Windows
# 683     Windows
# 684     Windows
# 685     Windows
# 686     Windows
# 687     Windows
# 688     Windows
# 689     Windows
# 690   Chrome OS
# 691     Windows
# 692     Windows
# 693     Windows
# 694     Windows
# 695     Windows
# 696     Windows
# 697   Chrome OS
# 698     Windows
# 700     Windows
# 701     Windows
# 702     Windows
# 703     Windows
# 704     Windows
# 705     Windows
# 706     Windows
# 707     Windows
# 708     Windows
# 709     Windows
# 710     Windows
# 711       Linux
# 712       Linux
# 713     Windows
# 714     Windows
# 715     Windows
# 716     Windows
# 717     Windows
# 718     Windows
# 719     Windows
# 720     Windows
# 721     Windows
# 722     Windows
# 723     Windows
# 724     Windows
# 725     Windows
# 727     Windows
# 728       Linux
# 729     Windows
# 730     Windows
# 731     Windows
# 732     Windows
# 733     Windows
# 734     Windows
# 735     Windows
# 736     Windows
# 737     Windows
# 738     Windows
# 739     Windows
# 740     Windows
# 741     Windows
# 742     Windows
# 743     Windows
# 744     Windows
# 745   Chrome OS
# 746     Windows
# 748     Windows
# 749     Windows
# 750     Windows
# 751     Windows
# 752     Windows
# 754     Windows
# 755     Windows
# 756     Windows
# 757     Windows
# 758     Windows
# 759     Windows
# 760     Windows
# 761     Windows
# 762   Chrome OS
# 763     Windows
# 764     Windows
# 765     Windows
# 766     Windows
# 767     Windows
# 768     Windows
# 769       Linux
# 770     Windows
# 771     Windows
# 772     Windows
# 773     Windows
# 775     Windows
# 776     Windows
# 777     Windows
# 778     Windows
# 779     Windows
# 780     Windows
# 781     Windows
# 782     Windows
# 783     Windows
# 784     Windows
# 785     Windows
# 786     Windows
# 787     Windows
# 788     Windows
# 789     Windows
# 790     Windows
# 791     Windows
# 792     Windows
# 793     Windows
# 794         Mac
# 795     Windows
# 796     Windows
# 797     Windows
# 798     Windows
# 799     Windows
# 800     Windows
# 801     Windows
# 802     Windows
# 803     Windows
# 804     Windows
# 805     Windows
# 806     Windows
# 807     Windows
# 808     Windows
# 809     Windows
# 810     Windows
# 811     Windows
# 812     Windows
# 813     Windows
# 814     Windows
# 815     Windows
# 816     Windows
# 817   Chrome OS
# 818     Windows
# 819     Windows
# 820     Windows
# 821     Windows
# 822     Windows
# 823     Windows
# 824     Windows
# 825     Windows
# 826     Windows
# 827     Windows
# 828   Chrome OS
# 829     Windows
# 830     Windows
# 831     Windows
# 832       Linux
# 833     Windows
# 834     Windows
# 835     Windows
# 836     Windows
# 837     Windows
# 838   Chrome OS
# 839     Windows
# 840     Windows
# 841     Windows
# 842     Windows
# 843     Windows
# 844     Windows
# 845     Windows
# 846   Chrome OS
# 847     Windows
# 848     Windows
# 849     Windows
# 850     Windows
# 851     Windows
# 852       Linux
# 853     Windows
# 854     Windows
# 855     Windows
# 856     Windows
# 857     Windows
# 858     Windows
# 859     Windows
# 860     Windows
# 861     Windows
# 862     Windows
# 863     Windows
# 864     Windows
# 865     Windows
# 866     Windows
# 867     Windows
# 868     Windows
# 869     Windows
# 870     Windows
# 871     Windows
# 872     Windows
# 873     Windows
# 874     Windows
# 875     Windows
# 876       Linux
# 877     Windows
# 878     Windows
# 879     Windows
# 880     Windows
# 881     Windows
# 882     Windows
# 883     Windows
# 884     Windows
# 885     Windows
# 886       Linux
# 887     Windows
# 888   Chrome OS
# 889     Windows
# 890     Windows
# 891     Windows
# 892     Windows
# 893     Windows
# 894     Windows
# 895     Windows
# 896       Linux
# 897     Windows
# 898     Windows
# 899     Windows
# 900     Windows
# 901     Windows
# 902     Windows
# 903     Windows
# 904     Windows
# 905     Windows
# 906     Windows
# 907   Chrome OS
# 908     Windows
# 909     Windows
# 910     Windows
# 911     Windows
# 912     Windows
# 913     Windows
# 914     Windows
# 915     Windows
# 916     Windows
# 917     Windows
# 918     Windows
# 919     Windows
# 920     Windows
# 921     Windows
# 924     Windows
# 925     Windows
# 926     Windows
# 927     Windows
# 928     Windows
# 929     Windows
# 930     Windows
# 931     Windows
# 932     Windows
# 933     Windows
# 934     Windows
# 935     Windows
# 936     Windows
# 937     Windows
# 939     Windows
# 940     Windows
# 941     Windows
# 942     Windows
# 943     Windows
# 944     Windows
# 945     Windows
# 946     Windows
# 947     Windows
# 948     Windows
# 949   Chrome OS
# 950     Windows
# 951     Windows
# 952     Windows
# 953   Chrome OS
# 954     Windows
# 955     Windows
# 956     Windows
# 957     Windows
# 958     Windows
# 959   Chrome OS
# 960     Windows
# 961     Windows
# 962     Windows
# 963     Windows
# 964     Windows
# 965       Linux
# 966     Windows
# 967     Windows
# 968     Windows
# 969     Windows
# 970     Windows
# 971     Windows
# 972     Windows
# 973     Windows
# 974     Windows
# 975     Windows
# 976     Windows
# 977     Windows
# 979     Windows
# 980     Windows
# 981     Windows
# 982     Windows
# 983     Windows
# 984     Windows
# 985     Windows
# 986     Windows
# 987     Windows
# 988     Windows
# 989     Windows
# 990     Windows
# 991     Windows
# 992     Windows
# 993     Windows
# 995     Windows
# 996     Windows
# 997     Windows
# 998     Windows
# 999     Windows
# 1000    Windows
# 1001    Windows
# 1002    Windows
# 1003    Windows
# 1004    Windows
# 1005    Windows
# 1006    Windows
# 1007    Windows
# 1008    Windows
# 1009    Windows
# 1010    Windows
# 1011    Windows
# 1012    Windows
# 1013    Windows
# 1014    Windows
# 1015    Windows
# 1016    Windows
# 1017    Windows
# 1018    Windows
# 1019    Windows
# 1020    Windows
# 1021    Windows
# 1022    Windows
# 1023    Windows
# 1024    Windows
# 1025    Windows
# 1026    Windows
# 1027    Windows
# 1028    Windows
# 1029    Windows
# 1030    Windows
# 1031    Windows
# 1032    Windows
# 1033    Windows
# 1034    Windows
# 1035    Windows
# 1036    Windows
# 1037    Windows
# 1038    Windows
# 1039    Windows
# 1040    Windows
# 1041    Windows
# 1042    Windows
# 1043    Windows
# 1044    Windows
# 1045    Windows
# 1046    Windows
# 1047    Windows
# 1048    Windows
# 1049  Chrome OS
# 1050    Windows
# 1051    Windows
# 1052    Windows
# 1053    Windows
# 1054    Windows
# 1055    Windows
# 1056    Windows
# 1057    Windows
# 1058    Windows
# 1059    Windows
# 1061    Windows
# 1062    Windows
# 1063    Windows
# 1064    Windows
# 1065    Windows
# 1066    Windows
# 1067    Windows
# 1068    Windows
# 1069        Mac
# 1070    Windows
# 1071    Windows
# 1072    Windows
# 1073    Windows
# 1074    Windows
# 1075    Windows
# 1076    Windows
# 1077    Windows
# 1078    Windows
# 1079    Windows
# 1080    Windows
# 1081    Windows
# 1082    Windows
# 1083    Windows
# 1084    Windows
# 1085    Windows
# 1086    Windows
# 1087    Windows
# 1088  Chrome OS
# 1089    Windows
# 1090      Linux
# 1091    Windows
# 1092    Windows
# 1093    Windows
# 1094    Windows
# 1095    Windows
# 1096    Windows
# 1097    Windows
# 1098    Windows
# 1099    Windows
# 1100    Windows
# 1101    Windows
# 1102  Chrome OS
# 1103    Windows
# 1104    Windows
# 1105    Windows
# 1106    Windows
# 1107    Windows
# 1108    Windows
# 1109    Windows
# 1110    Windows
# 1111    Windows
# 1112    Windows
# 1113    Windows
# 1114    Android
# 1115    Windows
# 1116    Windows
# 1117    Windows
# 1118    Windows
# 1119    Windows
# 1120    Windows
# 1121    Windows
# 1122    Windows
# 1123      Linux
# 1124    Windows
# 1125    Windows
# 1126    Windows
# 1127    Windows
# 1128    Windows
# 1129    Windows
# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %%
df.describe()
# Out:
#        Screen_Size(Inch)   Weight(Kg)          Price      RAM(GB)
# count        1273.000000  1273.000000    1273.000000  1273.000000
# mean           14.908311     2.051139   59955.311076     8.476826
# std             0.826555     0.620510   37332.247865     5.556143
# min            13.300000     1.100000    9270.000000     1.000000
# 25%            14.000000     1.600000   31914.000000     4.000000
# 50%            14.910000     2.000000   52161.000000     8.000000
# 75%            15.600000     2.300000   79333.000000     8.000000
# max            17.000000     4.400000  324954.000000    64.000000

# %%
df.describe(include='object')
# Out:
#        Company Type_Name  Screen_Resolution                   Processor   RAM  \
# count     1273      1273               1273                        1273  1273
# unique      19         7                 40                         118    10
# top     Lenovo  Notebook  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# freq       290       693                495                         183   608
#
#            Memory                    GPU       OpSys   Preference  \
# count        1273                   1273        1273         1273
# unique         39                    110           8            3
# top     256GB SSD  Intel HD Graphics 620  Windows 10  Entry-Level
# freq          402                    271        1110          532
#
#        Processor_Type    GPU_Type Weight_Category
# count            1273        1273            1273
# unique              3           2               3
# top             Intel  Integrated           Light
# freq             1210         703             672

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
sns.histplot(df["Price"],color="purple",kde=True)
plt.title("Distribution_Of_Laptop_Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
df["Price"].quantile(.99)
# Out:
# np.float64(167852.75999999998)

# %%
med_val = df["Screen_Size(Inch)"].median()
sns.boxplot(df["Screen_Size(Inch)"],color="yellow")
plt.axhline(med_val, color='red', linestyle='--', label=f"Median: {med_val:}")
plt.legend()
plt.show()

# %%
sns.countplot(df["RAM"],order=df["RAM"].value_counts(ascending=False).index,palette="husl")
plt.show()

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
df["Spec_Combo"] = df["RAM"] + " | " + df["Processor_Type"] + " | " + df["GPU_Type"]

plt.figure(figsize=(14, 6))
sns.boxplot(x="Spec_Combo", y="Price",palette="flare",data=df)
plt.xticks(rotation=90)
plt.title("Price by RAM + Processor + GPU")
plt.tight_layout()
plt.show()

# %%
plt.barh(width = "Screen_Size(Inch)", y ="Weight_Category",color="purple",data=df)
plt.xlabel("Screen_Inch")
plt.ylabel("Weight_Category")
plt.show()

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %%
corr_df = df[["Price", "RAM(GB)", "Weight(Kg)","Screen_Size(Inch)"]].corr()

sns.heatmap(corr_df, annot=True, cmap="flare")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df,hue="GPU_Type")
plt.suptitle("Price, RAM, Weight by GPU", y=1.02)
plt.show()

# %% [markdown]
# ## VISUALIZATION

# %%
company_data = df["Company"].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(19,6))
bars = ax.bar(company_data["Company"], company_data["count"], color="skyblue")
ax.bar_label(bars)

plt.title("Operating System Distribution")
plt.show()

# %%
laptype_data = df["Type_Name"].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(19,6))
bars = ax.bar(laptype_data["Type_Name"], laptype_data["count"], color="skyblue")
ax.bar_label(bars)

plt.title("Operating System Distribution")
plt.show()

# %%
plt.figure(figsize=(14, 6)) 
sns.violinplot(x="Type_Name",y="Price",data=df,palette="pastel")
plt.show()

# %%
preference_data = df["Preference"].value_counts().reset_index()

plt.pie(data=preference_data,x="count",labels="Preference",autopct = "%1.1f%%",colors = ['skyblue', 'lightgreen', 'orange'])
plt.legend(loc = "right",bbox_to_anchor = (2,0.5))
plt.title("Laptop Preference")
plt.show()

# %%
processor_data = df["Processor_Type"].value_counts().reset_index()

plt.pie(data=processor_data,x="count",labels="Processor_Type",autopct = "%1.1f%%",colors = ['lightgreen', 'skyblue', 'black'])
plt.legend(loc = "right",bbox_to_anchor = (2,0.5))
plt.title("Laptop Preference")
plt.show()

# %%
processor_data = df.query("Processor_Type=='Intel'")["Processor"].value_counts().nlargest(5).reset_index()

fig, ax = plt.subplots(figsize=(19,6))
bars = ax.bar(processor_data["Processor"], processor_data["count"], color="lightgreen")
ax.bar_label(bars)

plt.title("Top 5 Intel Processor")
plt.show()

# %%
graphics_data = df["GPU_Type"].value_counts().reset_index()

plt.pie(data=graphics_data,x="count",labels="GPU_Type",autopct = "%1.1f%%",colors = ["#AEC6CF", "#FFB6B9"])
plt.legend(loc = "right",bbox_to_anchor = (2,0.5))
plt.title("Graphics_Type Preference")
plt.show()

# %%
gpu_integrated_data = df.query("GPU_Type=='Integrated'")["GPU"].value_counts().nlargest(5).reset_index()

fig, ax = plt.subplots(figsize=(19,6))
bars = ax.bar(gpu_integrated_data["GPU"], gpu_integrated_data["count"], color="#AEC6CF")
ax.bar_label(bars)

plt.title("Top 5 GPU Processor")
plt.show()

# %% [markdown]
# ## STATISTICAL TEST

# %% [markdown]
# ### INDEPENDENT TTEST

# %%
integrated_data = df.query("GPU_Type=='Integrated'")["Price"]
dedicated_data = df.query("GPU_Type=='Dedicated'")["Price"]
alpha=0.05

# %%
stat_value,p_value = ttest_ind(integrated_data,dedicated_data,equal_var=True)

# %%
if p_value > alpha:
    print("Fail to reject Null Hypothesis: Both groups are same")
else:
    print("Reject Null Hypothesis: Both groups are not same")
# Out:
# Reject Null Hypothesis: Both groups are not same

# %%
stat_value
# Out:
# np.float64(-6.603907548461839)

# %%
p_value
# Out:
# np.float64(5.87032667468216e-11)

# %% [markdown]
# - ***T-test*** shows ***significant price difference*** between Integrated and Dedicated GPU laptops

# %% [markdown]
# ### TWO-WAY ANOVA

# %%
formula = "Price ~ C(Company) + C(RAM) + C(Preference) +  C(OS_Type) + C(Processor_Type) +C(GPU_Type)\
                    + C(Weight_Category)+ C(OS_Type):C(Processor_Type) +  C(Company):C(Processor_Type)"

model = ols(formula, data=df).fit()

anova_table = sm.stats.anova_lm(model, typ=3)

print(anova_table)
# Out:
#                                     sum_sq      df           F         PR(>F)
# Intercept                     3.408206e+09     1.0   16.698040   4.666070e-05
# C(Company)                    2.595438e+10    18.0    7.064442   1.922055e-17
# C(RAM)                        8.246194e+10     9.0   44.890112   5.116543e-70
# C(Preference)                 3.743242e+11     2.0  916.975008  1.236268e-244
# C(OS_Type)                    3.554978e+09     4.0    4.354282   1.683037e-03
# C(Processor_Type)             1.610712e+09     2.0    3.945731   1.958194e-02
# C(GPU_Type)                   3.634555e+09     1.0   17.807006   2.624096e-05
# C(Weight_Category)            1.727606e+09     2.0    4.232085   1.473376e-02
# C(OS_Type):C(Processor_Type)  6.717642e+09     8.0    4.114021   1.039761e-03
# C(Company):C(Processor_Type)  5.303187e+10    36.0    7.217289   9.815555e-19
# Residual                      2.514612e+11  1232.0         NaN            NaN

# %% [markdown]
# - ***RAM*** and User ***Preference*** have a strong, ***statistically significant*** impact on laptop price.
#
# - ***GPU_Type*** and ***Weight*** Category also show ***significant effects***, indicating performance and portability influence pricing.
#
# - ***Company***, ***OS_Type***, and ***Processor_Type*** have ***no significant effect*** on price when other specs are considered.
#
# - ***Interaction effects*** (e.g., OS × Processor, Company × Processor) are ***not significant***, suggesting these combinations do not jointly influence pricing.

# %% [markdown]
# ## INSIGHTS

# %% [markdown]
# - The Price feature is a significant factor and shows positive skewness. Most laptops are priced around ₹52,000, falling within the mid-range segment. About 99% of prices fall below ₹167,785.
#
# - The maximum laptop price is ₹324,954, which is not considered an outlier as it includes a dedicated GPU, indicating it’s a gaming laptop, thereby justifying the high price.
#
# - The Screen Size has a median of 14.91 inches with no outliers detected, meaning 50% of the screen sizes lie close to this value, showing a consistent trend in laptop displays.
#
# - The RAM configuration shows that 8GB is the most common with 608 laptops, followed by 4GB RAM at 362 units, highlighting a user preference for performance within budget.
#
# - When comparing Price vs RAM, Processor Type, and GPU Type, although some points appear as outliers, they are mostly high-end laptops with dedicated GPUs, commonly gaming models, which justifies the elevated prices.
#
# - By Weight category, moderate-weight laptops (≤ 3.5kg) are the most preferred, offering a balance between portability and performance.
#
# ***In the correlation analysis:***
#
# * Price is strongly correlated with RAM, likely due to the influence of high-tech processors.
#
# * There’s a moderate correlation with Weight.
#
# * Negligible correlation is observed with Screen Size, indicating it doesn’t heavily impact pricing.
#
# - Lenovo (290 units) and Dell (287 units) are the top-selling brands, likely due to their wide range of offerings and availability.
#
# - Lenovo dominates the entry-level segment, making it more attractive for budget-conscious buyers.
#
# - Notebook-type laptops are the most popular, with 717 units, far ahead of Gaming laptops at 202 units.
#
# - Specifically, Lenovo contributes 174 Notebook-type laptops, reinforcing its budget-friendly branding.
#
# ***In market segmentation:***
#
# * Entry-level laptops account for 41.8% of sales,
#
# * Followed by Mainstream/Mid-range at 31%, and
#
# * Premium/High-end at 27.2%.
#
# This clearly shows a strong price sensitivity among users.
#
# ***For Processor Type:***
#
# * Intel dominates with a 95.1% market share, likely due to its better perceived performance.
#
# * Among Intel models, Intel Core i5 U GHz is the most selected, with 183 units.
#
# ***For GPU Type:***
#
# * Integrated GPUs are preferred due to affordability and basic usage needs.
#
# * The most common GPU is Intel HD Graphics 620, present in 271 laptops.
#
# - An Independent T-test on GPU Type vs Price reveals a statistically significant price difference between Integrated and Dedicated GPUs, leading to rejection of the null hypothesis.
